# %%
#importing necessary libraries 

import pandas as pd  
import numpy as np

# %% [markdown]
# # Dataset -> Listings detailed

# %%
listings_detailed = pd.read_csv('listings2.csv', low_memory=False)
listings_detailed.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   6499   https://www.airbnb.com/rooms/6499  20200128033557   2020-01-28
# 1  25659  https://www.airbnb.com/rooms/25659  20200128033557   2020-01-28
# 2  28066  https://www.airbnb.com/rooms/28066  20200128033557   2020-01-29
# 3  29138  https://www.airbnb.com/rooms/29138  20200128033557   2020-01-28
# 4  29248  https://www.airbnb.com/rooms/29248  20200128033557   2020-01-28
#
#                                         name  \
# 0       Belém 1 Bedroom Historical Apartment
# 1  Sunny,  Alfama  Sleeps 3 - Coeur d'Alfama
# 2                              ear the birds
# 3              Room for rent in shared house
# 4   Apartamento Alfama com vista para o rio!
#
#                                              summary  \
# 0  This apartment is all about Location, next to ...
# 1  Sunny 1 Bedroom cozy apartment in historic Alf...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                space  \
# 0  Fully furnished apartment (35m2). Small inside...
# 1  Charming, sunny, cozy apartment in the heart o...
# 2  traditional farm house in a quiet place where ...
# 3  05 minutes from city center by subway, 10 minu...
# 4  Located in the city center, and great location...
#
#                                          description experiences_offered  \
# 0  This apartment is all about Location, next to ...                none
# 1  Sunny 1 Bedroom cozy apartment in historic Alf...                none
# 2  traditional farm house in a quiet place where ...                none
# 3  05 minutes from city center by subway, 10 minu...                none
# 4  Located in the city center, and great location...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  To get  to the city center, tram 15 stops in f...  ...                t
# 1  Alfama is the oldest and most picturesque quar...  ...                t
# 2                                                NaN  ...                f
# 3                                                NaN  ...                f
# 4                                                NaN  ...                t
#
#   is_business_travel_ready cancellation_policy require_guest_profile_picture  \
# 0                        f            moderate                             f
# 1                        f            moderate                             f
# 2                        f            flexible                             f
# 3                        f            flexible                             f
# 4                        f            moderate                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               1
# 1                                f                               1
# 2                                f                               1
# 3                                f                               1
# 4                                f                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.39
# 1                                            0               1.61
# 2                                            0                NaN
# 3                                            0                NaN
# 4                                            0               2.89
#
# [5 rows x 106 columns]

# %%
listings_detailed.shape
# Out:
# (25002, 106)

# %%
len(listings_detailed.columns.tolist())
# Out:
# 106

# %%
print(listings_detailed.columns.tolist())
# Out:
# ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'street', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code', 'country', 'latitude', 'longitude', 'is_location_exact', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'requires_license', 'license', 'jurisdiction_names', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']

# %%
#let's remove columns we think won't be useful
low_variance = []

for col in listings_detailed._get_numeric_data():
    minimum = min(listings_detailed[col])
    ninety_perc = np.percentile(listings_detailed[col], 90)
    if ninety_perc == minimum:
        low_variance.append(col)

print(low_variance)
# Out:
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# ['scrape_id', 'calculated_host_listings_count_shared_rooms']

# %%
#host_acceptance_rate: All column values are N/A
#country_code and country (All PT)
#business travel ready is all F
#requires licence 
#availability_30,60, etc.... -> availability for the future
#neighbourhood_cleansed too detailed
#scores ratings other than 'review_scores_rating' left since the latest is a weighted average
#'cleaning_fee' included in price
#licence doesnt tell anything about the listing or neighbour since it lisbon is mandatory to have licence 
'''
'instant_bookable',
 'cancellation_policy',
 'require_guest_profile_picture',
 'require_guest_phone_verification',

to buld a flexiblity scale

'''

columns_to_remove = ['neighbourhood',"scrape_id",'listing_url',"last_scraped","experiences_offered","notes","transit","access","interaction",'number_of_reviews_ltm',
                     "thumbnail_url","house_rules","medium_url","picture_url","xl_picture_url","host_name","host_about",
                     "host_acceptance_rate","host_url","host_thumbnail_url","host_picture_url","host_neighbourhood","host_verifications",
                     "state","market","smart_location","country",'country_code',"minimum_minimum_nights","maximum_minimum_nights",
                     "minimum_maximum_nights",'maximum_maximum_nights',"minimum_nights_avg_ntm","maximum_nights_avg_ntm","calendar_last_scraped",
                     "jurisdiction_names", "street", "calendar_updated", "has_availability", "is_location_exact", "city", "zipcode", 
                     "is_business_travel_ready", "weekly_price", "monthly_price",'maximum_nights', 'availability_30',
                     'availability_60','availability_90','availability_365','square_feet', 'latitude','longitude',
                     "host_id","host_since", "host_location", "host_response_time",'host_response_rate','host_listings_count',
                     'host_total_listings_count','host_has_profile_pic','host_identity_verified','summary','space',
                     'review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication',
                     'review_scores_location','review_scores_value', 'cleaning_fee', 'security_deposit','extra_people',
                     'requires_license','license', 'calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms',
                     'calculated_host_listings_count_shared_rooms']

data = listings_detailed.drop(columns_to_remove, axis =1)

# %% [markdown]
# # Final Columns

# %%
print(data.columns.tolist())
# Out:
# ['id', 'name', 'description', 'neighborhood_overview', 'host_is_superhost', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price', 'guests_included', 'minimum_nights', 'number_of_reviews', 'first_review', 'last_review', 'review_scores_rating', 'instant_bookable', 'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification', 'calculated_host_listings_count', 'reviews_per_month']

# %%
#We can use the info() method to output some general information about the dataframe:

len(data.columns.tolist())
# Out:
# 28

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25002 entries, 0 to 25001
# Data columns (total 28 columns):
# id                                  25002 non-null int64
# name                                24982 non-null object
# description                         24675 non-null object
# neighborhood_overview               17092 non-null object
# host_is_superhost                   25002 non-null object
# neighbourhood_cleansed              25002 non-null object
# neighbourhood_group_cleansed        25002 non-null object
# property_type                       25002 non-null object
# room_type                           25002 non-null object
# accommodates                        25002 non-null int64
# bathrooms                           24973 non-null float64
# bedrooms                            24992 non-null float64
# beds                                24891 non-null float64
# bed_type                            25002 non-null object
# amenities                           25002 non-null object
# price                               25002 non-null object
# guests_included                     25002 non-null int64
# minimum_nights                      25002 non-null int64
# number_of_reviews                   25002 non-null int64
# first_review                        21122 non-null object
# last_review                         21122 non-null object
# review_scores_rating                20935 non-null float64
# instant_bookable                    25002 non-null object
# cancellation_policy                 25002 non-null object
# require_guest_profile_picture       25002 non-null object
# require_guest_phone_verification    25002 non-null object
# calculated_host_listings_count      25002 non-null int64
# reviews_per_month                   21122 non-null float64
# dtypes: float64(5), int64(6), object(17)
# memory usage: 5.3+ MB
# None

# %%
data.describe()
# Out:
#                  id  accommodates     bathrooms      bedrooms          beds  \
# count  2.500200e+04  25002.000000  24973.000000  24992.000000  24891.000000
# mean   2.182569e+07      4.043916      1.438574      1.657050      2.530834
# std    1.159542e+07      2.379867      0.909724      1.325917      2.156652
# min    6.499000e+03      1.000000      0.000000      0.000000      0.000000
# 25%    1.324810e+07      2.000000      1.000000      1.000000      1.000000
# 50%    2.230370e+07      4.000000      1.000000      1.000000      2.000000
# 75%    3.159456e+07      5.000000      2.000000      2.000000      3.000000
# max    4.188291e+07     32.000000     24.000000    100.000000    100.000000
#
#        guests_included  minimum_nights  number_of_reviews  \
# count     25002.000000    25002.000000       25002.000000
# mean          2.040837        2.928966          41.881689
# std           1.662920       13.893752          64.687500
# min           1.000000        1.000000           0.000000
# 25%           1.000000        1.000000           2.000000
# 50%           2.000000        2.000000          14.000000
# 75%           2.000000        3.000000          54.000000
# max          20.000000     1000.000000         866.000000
#
#        review_scores_rating  calculated_host_listings_count  reviews_per_month
# count          20935.000000                    25002.000000       21122.000000
# mean              92.449773                       15.160707           1.642763
# std                8.565025                       41.948986           1.581443
# min               20.000000                        1.000000           0.010000
# 25%               90.000000                        1.000000           0.380000
# 50%               95.000000                        3.000000           1.130000
# 75%               98.000000                       10.000000           2.500000
# max              100.000000                      323.000000          17.720000

# %%
### MISSING VALUES ###

null_cols = data.isnull().sum()
null_cols[null_cols > 0]
# Out:
# name                       20
# description               327
# neighborhood_overview    7910
# bathrooms                  29
# bedrooms                   10
# beds                      111
# first_review             3880
# last_review              3880
# review_scores_rating     4067
# reviews_per_month        3880
# dtype: int64

# %%
#makes sense that last review and reviews per month 
#have missing values when number_of_reviews=0. Let's check that:

null_review = data[(data['last_review'].isnull()==True)| (data['reviews_per_month'].isnull()==True)]
null_review['number_of_reviews']

#What to do with the missing values?
#We can see that last_review reviews_per_month is null when number of reviews zero, 
#which makes total sense! Therefore it makes sense to replace the null values with zeros
# Out:
# 2        0
# 3        0
# 17       0
# 38       0
# 41       0
# 43       0
# 46       0
# 48       0
# 50       0
# 57       0
# 64       0
# 65       0
# 68       0
# 96       0
# 103      0
# 105      0
# 117      0
# 118      0
# 134      0
# 136      0
# 137      0
# 143      0
# 153      0
# 198      0
# 221      0
# 287      0
# 291      0
# 305      0
# 309      0
# 325      0
#         ..
# 24972    0
# 24973    0
# 24974    0
# 24975    0
# 24976    0
# 24977    0
# 24978    0
# 24979    0
# 24980    0
# 24981    0
# 24982    0
# 24983    0
# 24984    0
# 24985    0
# 24986    0
# 24987    0
# 24988    0
# 24989    0
# 24990    0
# 24991    0
# 24992    0
# 24993    0
# 24994    0
# 24995    0
# 24996    0
# 24997    0
# 24998    0
# 24999    0
# 25000    0
# 25001    0
# Name: number_of_reviews, Length: 3880, dtype: int64

# %%
data['neighbourhood_group_cleansed'].unique()
# Out:
# array(['Lisboa', 'Azambuja', 'Cascais', 'Sintra', 'Alenquer', 'Oeiras',
#        'Vila Franca De Xira', 'Mafra', 'Torres Vedras', 'Lourinh',
#        'Loures', 'Cadaval', 'Amadora', 'Sobral De Monte Agrao',
#        'Arruda Dos Vinhos', 'Odivelas'], dtype=object)

# %% [markdown]
# # Lisbon city only

# %%
#####  WE WANT TO ANALYSE DATA IN LISBON ONLY!! #######
data = data[(data['neighbourhood_group_cleansed']=='Lisboa')]

data.head()
# Out:
#       id                                       name  \
# 0   6499       Belém 1 Bedroom Historical Apartment
# 1  25659  Sunny,  Alfama  Sleeps 3 - Coeur d'Alfama
# 3  29138              Room for rent in shared house
# 4  29248   Apartamento Alfama com vista para o rio!
# 5  29396           Alfama Hill - Boutique apartment
#
#                                          description  \
# 0  This apartment is all about Location, next to ...
# 1  Sunny 1 Bedroom cozy apartment in historic Alf...
# 3  05 minutes from city center by subway, 10 minu...
# 4  Located in the city center, and great location...
# 5  Feel at home in the historic centre of Lisbon....
#
#                                neighborhood_overview host_is_superhost  \
# 0  To get  to the city center, tram 15 stops in f...                 f
# 1  Alfama is the oldest and most picturesque quar...                 t
# 3                                                NaN                 f
# 4                                                NaN                 f
# 5  Great neighborhood in the old part of town. Am...                 f
#
#   neighbourhood_cleansed neighbourhood_group_cleansed property_type  \
# 0                   Belm                       Lisboa     Apartment
# 1      Santa Maria Maior                       Lisboa     Apartment
# 3                Areeiro                       Lisboa     Apartment
# 4      Santa Maria Maior                       Lisboa     Apartment
# 5      Santa Maria Maior                       Lisboa     Apartment
#
#          room_type  accommodates  ...  number_of_reviews  first_review  \
# 0  Entire home/apt             3  ...                 26    2014-09-02
# 1  Entire home/apt             3  ...                113    2014-04-24
# 3     Private room             1  ...                  0           NaN
# 4  Entire home/apt             4  ...                319    2011-01-01
# 5  Entire home/apt             4  ...                232    2012-05-22
#
#    last_review review_scores_rating instant_bookable  \
# 0   2020-01-03                 91.0                t
# 1   2019-12-08                 96.0                t
# 3          NaN                  NaN                f
# 4   2019-10-29                 91.0                t
# 5   2020-01-12                 96.0                t
#
#            cancellation_policy  require_guest_profile_picture  \
# 0                     moderate                              f
# 1                     moderate                              f
# 3                     flexible                              f
# 4                     moderate                              f
# 5  strict_14_with_grace_period                              f
#
#    require_guest_phone_verification  calculated_host_listings_count  \
# 0                                 f                               1
# 1                                 f                               1
# 3                                 f                               1
# 4                                 f                               1
# 5                                 t                               2
#
#   reviews_per_month
# 0              0.39
# 1              1.61
# 3               NaN
# 4              2.89
# 5              2.48
#
# [5 rows x 28 columns]

# %%
data.shape
# Out:
# (18265, 28)

# %%
#the below listings don't have enough information for our quality analysis 
null_displ = data[(data['last_review'].isnull()==True)|(data['first_review'].isnull()==True)]
null_displ['review_scores_rating']
# Out:
# 3       NaN
# 17      NaN
# 38      NaN
# 43      NaN
# 64      NaN
# 105     NaN
# 117     NaN
# 118     NaN
# 153     NaN
# 198     NaN
# 305     NaN
# 385     NaN
# 389     NaN
# 395     NaN
# 398     NaN
# 550     NaN
# 610     NaN
# 628     NaN
# 673     NaN
# 701     NaN
# 772     NaN
# 863     NaN
# 925     NaN
# 981     NaN
# 1002    NaN
# 1025    NaN
# 1055    NaN
# 1135    NaN
# 1139    NaN
# 1196    NaN
#          ..
# 24970   NaN
# 24971   NaN
# 24972   NaN
# 24973   NaN
# 24974   NaN
# 24976   NaN
# 24977   NaN
# 24978   NaN
# 24979   NaN
# 24980   NaN
# 24981   NaN
# 24982   NaN
# 24983   NaN
# 24984   NaN
# 24985   NaN
# 24986   NaN
# 24987   NaN
# 24988   NaN
# 24990   NaN
# 24991   NaN
# 24992   NaN
# 24993   NaN
# 24994   NaN
# 24995   NaN
# 24996   NaN
# 24997   NaN
# 24998   NaN
# 24999   NaN
# 25000   NaN
# 25001   NaN
# Name: review_scores_rating, Length: 2532, dtype: float64

# %%
data = data.dropna(subset=['last_review','first_review'])
data
# Out:
#              id                                               name  \
# 0          6499               Belém 1 Bedroom Historical Apartment
# 1         25659          Sunny,  Alfama  Sleeps 3 - Coeur d'Alfama
# 4         29248           Apartamento Alfama com vista para o rio!
# 5         29396                   Alfama Hill - Boutique apartment
# 6         29720                        TheHOUSE - Your luxury home
# 7         29915                     MODERN  AND COOL APT IN LISBON
# 8         33348                                       Happy Season
# 9         40817                 Chiado, Alecrim walk to Riverfront
# 10        42519            Nice Apart.BAIRRO ALTO (ADAMASTOR) 6-1º
# 11        48025                   Apartment for renting  in Lisbon
# 16        50108                                    Duplex do Pipas
# 18        55116                                       Sonho Lisboa
# 19        56906                Lisbon Balcony Penthouse 15th Floor
# 20        65878                                      Caetanos Loft
# 21        75171                        Art Museum Apartm - 7680/AL
# 22        76132                    A Romantic Renewed Apartment T1
# 23        83615                         Sleep 4 - Tram 28 - 302/AL
# 25        83933                Charming flat with terrace in Graça
# 26        84599   LV Premier Baixa PR- Elevator, Balcony, AC, View
# 27        85270                  Spacious Sunny Flat -Baixa/Rossio
# 28        88312                 Appart lumineux coeur de Lisbonne.
# 29        88410                                      LISBOA PÁTRIA
# 30        89015                   GREAT LUXURY HOUSE IN THE CENTER
# 31        90931                    NORONHA apartment - BAIRRO ALTO
# 32        93829                      Studio near to S Jorge Castle
# 33        95212                     Big3 bd CHARM in Perfect Spot!
# 34        97503                Lovely equipped flat in city centre
# 35       103252                               BALCONY · Vila Berta
# 39       108058  ROOM+Bathroom - 15 min to Center City (metro R...
# 42       119120                Lapa 2Bdr with City and River Views
# ...         ...                                                ...
# 24607  41178741                Best Room in the center Bairro alto
# 24608  41178908  Big room with closet in Bairro Alto Lisbon Center
# 24610  41192441                   Olá Lisbon - Panoramic Graça III
# 24625  41250336  Studio with GARAGE -  Liberdade 40 - Wi-FI and...
# 24626  41251727  Spacious, Stylish & Sunny New Apt W/Terrace- Lapa
# 24638  41259029                               Cosy Bica Apartement
# 24641  41262134                        ALMIRANTE BALCONY by HOMING
# 24644  41278299  Triangularcamping Autocaravana Sol, Mar & Natu...
# 24645  41281992  Casa Adelaide -Penthouse +amazing terrace and ...
# 24648  41301275  Double room with balcony "Dom Pedro II" Sé Alfama
# 24657  41313937                            Encarnação Metro 1  1/2
# 24703  41391730                                          Paraiso 7
# 24712  41396381                         MARQUES PRESTIGE by HOMING
# 24715  41397822                      CHARMING ALEGRIA II by HOMING
# 24721  41397838                        MARQUES DELIGHT I by HOMING
# 24724  41397843                          SWEET ALMIRANTE by HOMING
# 24725  41397845                            GRAÇA STYLISH by HOMING
# 24732  41403386          Charming Apartment Blue Bairro Guesthouse
# 24739  41429051       Prime Location Luxury Apartment with balcony
# 24740  41429288   Madragoa Trendy Apartment Ideal for 3, 2 or solo
# 24744  41444855          NEW FLAT IN SALDANHA CLOSE TO ATTRACTIONS
# 24745  41448963                  Cozy room in the center of Lisbon
# 24761  41476861                                   Home Bairro Alto
# 24793  41553851                           ALFAMA CONCEPT by HOMING
# 24794  41553852                           ALFAMA PREMIUM by HOMING
# 24795  41553855                  GRAND PARLIAMENT DUPLEX by HOMING
# 24797  41553859                      PRINCIPE REAL VIEWS by HOMING
# 24798  41553861                             LAPA TERRACE by HOMING
# 24818  41575078                                   Center of lisbon
# 24898  41712909                 São Lázaro near Baixa by Innkeeper
#
#                                              description  \
# 0      This apartment is all about Location, next to ...
# 1      Sunny 1 Bedroom cozy apartment in historic Alf...
# 4      Located in the city center, and great location...
# 5      Feel at home in the historic centre of Lisbon....
# 6      A house at the top of an anonimous building, T...
# 7      A modern and equipped apartment. Quiet and pea...
# 8      Five minutes by foot to subway Campo Grande, y...
# 9      Street of Alecrim, (18th c. Street of the Ital...
# 10     O apartamento esta muito bem localizado num ba...
# 11     Located in the heart of old Lisbon (Bairro Alt...
# 16     The apartment is located in the upmarket distr...
# 18     Nice and quiet room in the city center. Spacio...
# 19     Hi, First of all thanks for looking my apartme...
# 20     Registration number of local accommodation: 36...
# 21     CHARMING - FULLY STOCKED - SUNNY Space and lig...
# 22     Fully renewed one bedroom apartment located in...
# 23     familie of 2- quiet - central - classic taste ...
# 25     The apartment has been furnished with care and...
# 26     LV Premier Baixa Apartments – PR is a sought-a...
# 27     Official Local Lodging Registry number: 1533/A...
# 28     Bright apartment with a vintage and personaliz...
# 29     LISBOA PÁTRIA You can easily find a nice bed, ...
# 30     (#)This unique and luxurious two-bedroom cotta...
# 31     wonderful typical lisbonense apartment. THE AP...
# 32     The house is located in the historic quarter G...
# 33     Big apartment, 115 m2, Charm and Design in his...
# 34     Beautiful apartment in city center, 2 rooms fo...
# 35     Sunny Balcony on first floor apartment (with s...
# 39     Gosto da minha casa porque é confortável e tem...
# 42     Charming two bedroom with City and River Views...
# ...                                                  ...
# 24607                                                NaN
# 24608                                                NaN
# 24610  In Lisbon be Lisboeta and accept our invitatio...
# 24625  The PERFECT studio apartment, in the heart of ...
# 24626  Located in the neighbourhood of Lapa, one of t...
# 24638  No bairro da Bica, Sta. Catarina, um pequeno a...
# 24641  The apartment in Lisbon has 1 bedrooms and has...
# 24644  Viajar sobre rodas, conhecer Portugal e outros...
# 24645  Olá companheiros amantes de viagens! Esta é a ...
# 24648  A very spacious and sunny double room (16,94 m...
# 24657  Excelente apartamento de dois quartos, cozinha...
# 24703  Paraiso VII apartment is peacefully located at...
# 24712  This brand new deluxe apartment, recently reno...
# 24715  This elegant and comfortable apartment is loca...
# 24721  A brand new apartment, recently renovated, is ...
# 24724  This stylish and new apartment was recently de...
# 24725  This stylish and vintage apartment recently re...
# 24732  Blue Bairro Guesthouse e um acolhedor Apartame...
# 24739  Decorated by professionals this outstanding ap...
# 24740  One-bedroom apartment ideal for relaxing holid...
# 24744  New flat in the heart of Saldanha and Alameda,...
# 24745  Comfortable, bright and cozy apartment, comple...
# 24761  Located in Bairro Alto, this apartment has a b...
# 24793  Located in Alfama, the most typical neighborho...
# 24794  Alfama Premium is a brand new apartment locate...
# 24795  This marvellous apartment is located near the ...
# 24797  This bright new partment in Príncipe Real with...
# 24798  This marvellous apartment has a terrace with v...
# 24818  located in heart of city close to Metro transp...
# 24898  Welcome to Lisbon! A beautifully designed apar...
#
#                                    neighborhood_overview host_is_superhost  \
# 0      To get  to the city center, tram 15 stops in f...                 f
# 1      Alfama is the oldest and most picturesque quar...                 t
# 4                                                    NaN                 f
# 5      Great neighborhood in the old part of town. Am...                 f
# 6      Location in the city's Embassies area, near en...                 t
# 7      Location: Entrecampos, Avenida das Forças Arma...                 f
# 8                                                    NaN                 f
# 9      Located a few steps away, (5 mn walk), from th...                 f
# 10     O bairro e muito sossegado apesar do movimento...                 f
# 11                                                   NaN                 f
# 16                                                   NaN                 f
# 18                                                   NaN                 f
# 19                                                   NaN                 f
# 20     Enjoy a cosy supper at home before heading out...                 f
# 21     Neighborhood and location: Located downtown Li...                 f
# 22     Campolide was once a good farmland. Nowadays t...                 f
# 23                                                   NaN                 f
# 25     Graça area is one of the lastest authentic are...                 f
# 26     The district of Baixa, frequently referred as ...                 t
# 27     The neighborhood is perfect for our guests to ...                 t
# 28                                                   NaN                 t
# 29                                                   NaN                 f
# 30                                                   NaN                 f
# 31     Nearby you have various forms of traditional P...                 f
# 32                                                   NaN                 f
# 33     Since being branded the Santos Design District...                 f
# 34                                                   NaN                 f
# 35     Vila Berta is a rare and proud remain of the m...                 t
# 39                A very friendly neighborhood and safe.                 t
# 42     Lapa is a unique neighborhood with façades cov...                 t
# ...                                                  ...               ...
# 24607                                                NaN                 t
# 24608                                                NaN                 t
# 24610  The apartment is in Graça, one of Lisbon's old...                 f
# 24625  Avenida da Liberdade (Portuguese for "Avenue o...                 f
# 24626  The historical neighborhood of Lapa, is one of...                 f
# 24638  O Bairro de Santa Catarina é um bairro alegre ...                 t
# 24641                                                NaN                 f
# 24644                                                NaN                 f
# 24645  Este é um bairro único, um lugar muito especia...                 f
# 24648  The apartement is very well situated, in an ty...                 f
# 24657  O bairro dos Olivais foi desenvolvido durante ...                 f
# 24703  Paraiso VII apartment is peacefully located at...                 f
# 24712                                                NaN                 f
# 24715                                                NaN                 f
# 24721                                                NaN                 f
# 24724                                                NaN                 f
# 24725                                                NaN                 f
# 24732  Estamos localizados em um dos bairros mais imp...                 f
# 24739  Most exclusive and central neighborhood in Lis...                 f
# 24740  Madragoa is one of the most traditional neighb...                 f
# 24744                                                NaN                 f
# 24745                                                NaN                 f
# 24761  To set forth on a discovery of Lisbon, there i...                 t
# 24793                                                NaN                 f
# 24794                                                NaN                 f
# 24795                                                NaN                 f
# 24797                                                NaN                 f
# 24798                                                NaN                 f
# 24818                                                NaN                 f
# 24898                                                NaN                 f
#
#       neighbourhood_cleansed neighbourhood_group_cleansed      property_type  \
# 0                       Belm                       Lisboa          Apartment
# 1          Santa Maria Maior                       Lisboa          Apartment
# 4          Santa Maria Maior                       Lisboa          Apartment
# 5          Santa Maria Maior                       Lisboa          Apartment
# 6                    Estrela                       Lisboa          Apartment
# 7             Avenidas Novas                       Lisboa          Apartment
# 8                     Lumiar                       Lisboa          Apartment
# 9                Misericrdia                       Lisboa          Apartment
# 10               Misericrdia                       Lisboa          Apartment
# 11               Misericrdia                       Lisboa          Apartment
# 16                   Estrela                       Lisboa          Apartment
# 18            Avenidas Novas                       Lisboa  Bed and breakfast
# 19                So Vicente                       Lisboa          Apartment
# 20               Misericrdia                       Lisboa               Loft
# 21                   Estrela                       Lisboa          Apartment
# 22                 Campolide                       Lisboa          Apartment
# 23                   Estrela                       Lisboa          Apartment
# 25                So Vicente                       Lisboa          Apartment
# 26         Santa Maria Maior                       Lisboa          Apartment
# 27         Santa Maria Maior                       Lisboa          Apartment
# 28              Santo Antnio                       Lisboa          Apartment
# 29                So Vicente                       Lisboa          Apartment
# 30               Misericrdia                       Lisboa              House
# 31              Santo Antnio                       Lisboa          Apartment
# 32                So Vicente                       Lisboa        Guest suite
# 33                   Estrela                       Lisboa          Apartment
# 34              Santo Antnio                       Lisboa          Apartment
# 35                So Vicente                       Lisboa          Apartment
# 39                  Alvalade                       Lisboa          Apartment
# 42                   Estrela                       Lisboa          Apartment
# ...                      ...                          ...                ...
# 24607            Misericrdia                       Lisboa          Apartment
# 24608            Misericrdia                       Lisboa          Apartment
# 24610             So Vicente                       Lisboa          Apartment
# 24625           Santo Antnio                       Lisboa          Apartment
# 24626                Estrela                       Lisboa          Apartment
# 24638            Misericrdia                       Lisboa          Apartment
# 24641                Arroios                       Lisboa          Apartment
# 24644         Penha de Frana                       Lisboa          Camper/RV
# 24645                Estrela                       Lisboa               Loft
# 24648      Santa Maria Maior                       Lisboa          Apartment
# 24657                Olivais                       Lisboa          Apartment
# 24703      Santa Maria Maior                       Lisboa          Apartment
# 24712           Santo Antnio                       Lisboa          Apartment
# 24715           Santo Antnio                       Lisboa          Apartment
# 24721           Santo Antnio                       Lisboa          Apartment
# 24724                Arroios                       Lisboa          Apartment
# 24725             So Vicente                       Lisboa          Apartment
# 24732         Avenidas Novas                       Lisboa  Bed and breakfast
# 24739           Santo Antnio                       Lisboa          Apartment
# 24740                Estrela                       Lisboa          Apartment
# 24744                Arroios                       Lisboa          Apartment
# 24745                Arroios                       Lisboa          Apartment
# 24761            Misericrdia                       Lisboa          Apartment
# 24793      Santa Maria Maior                       Lisboa          Apartment
# 24794      Santa Maria Maior                       Lisboa          Apartment
# 24795            Misericrdia                       Lisboa          Apartment
# 24797            Misericrdia                       Lisboa          Apartment
# 24798                Estrela                       Lisboa          Apartment
# 24818                Arroios                       Lisboa          Apartment
# 24898                Arroios                       Lisboa          Apartment
#
#              room_type  accommodates  ...  number_of_reviews  first_review  \
# 0      Entire home/apt             3  ...                 26    2014-09-02
# 1      Entire home/apt             3  ...                113    2014-04-24
# 4      Entire home/apt             4  ...                319    2011-01-01
# 5      Entire home/apt             4  ...                232    2012-05-22
# 6      Entire home/apt            16  ...                 52    2011-01-05
# 7      Entire home/apt             3  ...                 37    2010-07-24
# 8         Private room             6  ...                  2    2011-06-29
# 9      Entire home/apt             2  ...                358    2011-01-07
# 10     Entire home/apt             2  ...                113    2011-10-12
# 11     Entire home/apt             2  ...                 17    2011-07-18
# 16     Entire home/apt             4  ...                 37    2011-12-13
# 18        Private room             2  ...                  4    2016-08-12
# 19     Entire home/apt             2  ...                140    2011-01-05
# 20     Entire home/apt             4  ...                 53    2011-05-17
# 21     Entire home/apt             5  ...                 25    2011-08-10
# 22     Entire home/apt             2  ...                 10    2018-08-14
# 23     Entire home/apt             2  ...                 18    2012-06-07
# 25     Entire home/apt             3  ...                212    2011-08-16
# 26     Entire home/apt             5  ...                 69    2012-06-21
# 27     Entire home/apt             5  ...                180    2011-05-25
# 28     Entire home/apt             4  ...                 91    2011-05-18
# 29     Entire home/apt             4  ...                 36    2011-04-27
# 30     Entire home/apt             4  ...                 28    2011-08-23
# 31     Entire home/apt             4  ...                 16    2012-05-08
# 32     Entire home/apt             2  ...                 60    2014-05-26
# 33     Entire home/apt             6  ...                 74    2012-07-17
# 34        Private room             1  ...                 41    2011-07-14
# 35     Entire home/apt             4  ...                 58    2016-07-09
# 39        Private room             1  ...                 71    2015-05-25
# 42     Entire home/apt             4  ...                222    2011-08-08
# ...                ...           ...  ...                ...           ...
# 24607     Private room             2  ...                  5    2020-01-02
# 24608     Private room             2  ...                  2    2020-01-05
# 24610  Entire home/apt             6  ...                  1    2020-01-17
# 24625  Entire home/apt             2  ...                  1    2020-01-07
# 24626  Entire home/apt             5  ...                  1    2020-01-24
# 24638  Entire home/apt             2  ...                  1    2020-01-27
# 24641  Entire home/apt             4  ...                  1    2020-01-24
# 24644  Entire home/apt             5  ...                  1    2020-01-16
# 24645  Entire home/apt             5  ...                  2    2020-01-17
# 24648     Private room             2  ...                  2    2020-01-22
# 24657  Entire home/apt             5  ...                  1    2020-01-27
# 24703  Entire home/apt             4  ...                  1    2020-01-23
# 24712  Entire home/apt             6  ...                  1    2020-01-24
# 24715  Entire home/apt             4  ...                  1    2020-01-21
# 24721  Entire home/apt             4  ...                  2    2020-01-18
# 24724  Entire home/apt             4  ...                  1    2020-01-27
# 24725  Entire home/apt             4  ...                  1    2020-01-22
# 24732     Private room             6  ...                  4    2020-01-15
# 24739  Entire home/apt            16  ...                  4    2020-01-13
# 24740  Entire home/apt             3  ...                  1    2020-01-24
# 24744  Entire home/apt             6  ...                  1    2020-01-14
# 24745     Private room             2  ...                  2    2020-01-20
# 24761  Entire home/apt             4  ...                  1    2020-01-22
# 24793  Entire home/apt             4  ...                  2    2020-01-21
# 24794  Entire home/apt             6  ...                  1    2020-01-26
# 24795  Entire home/apt             8  ...                  3    2020-01-23
# 24797  Entire home/apt             4  ...                  1    2020-01-23
# 24798  Entire home/apt             6  ...                  2    2020-01-23
# 24818     Private room             2  ...                  1    2020-01-23
# 24898  Entire home/apt             4  ...                  1    2020-01-27
#
#        last_review review_scores_rating instant_bookable  \
# 0       2020-01-03                 91.0                t
# 1       2019-12-08                 96.0                t
# 4       2019-10-29                 91.0                t
# 5       2020-01-12                 96.0                t
# 6       2020-01-03                 98.0                f
# 7       2020-01-21                 93.0                f
# 8       2011-07-22                100.0                f
# 9       2020-01-11                 88.0                t
# 10      2019-12-30                 88.0                t
# 11      2019-12-03                 84.0                f
# 16      2019-11-05                 90.0                t
# 18      2019-12-13                100.0                f
# 19      2019-12-09                 92.0                t
# 20      2018-09-13                 96.0                t
# 21      2019-08-21                 92.0                f
# 22      2019-09-12                 92.0                t
# 23      2018-04-30                 87.0                f
# 25      2019-10-06                 88.0                t
# 26      2020-01-02                 92.0                t
# 27      2019-12-12                 99.0                t
# 28      2019-12-09                 95.0                t
# 29      2020-01-02                 94.0                f
# 30      2019-01-04                 95.0                f
# 31      2018-07-25                 88.0                f
# 32      2019-06-09                 90.0                t
# 33      2020-01-02                 94.0                f
# 34      2018-06-27                 83.0                f
# 35      2020-01-02                 96.0                t
# 39      2020-01-11                 98.0                t
# 42      2020-01-11                 97.0                t
# ...            ...                  ...              ...
# 24607   2020-01-21                 92.0                t
# 24608   2020-01-25                 80.0                f
# 24610   2020-01-17                100.0                t
# 24625   2020-01-07                100.0                t
# 24626   2020-01-24                 80.0                t
# 24638   2020-01-27                 60.0                t
# 24641   2020-01-24                100.0                t
# 24644   2020-01-16                100.0                f
# 24645   2020-01-18                100.0                t
# 24648   2020-01-26                100.0                f
# 24657   2020-01-27                  NaN                t
# 24703   2020-01-23                100.0                t
# 24712   2020-01-24                100.0                t
# 24715   2020-01-21                100.0                t
# 24721   2020-01-21                 90.0                t
# 24724   2020-01-27                100.0                t
# 24725   2020-01-22                100.0                t
# 24732   2020-01-25                 95.0                t
# 24739   2020-01-16                 90.0                t
# 24740   2020-01-24                 80.0                t
# 24744   2020-01-14                100.0                t
# 24745   2020-01-25                100.0                t
# 24761   2020-01-22                100.0                t
# 24793   2020-01-22                100.0                t
# 24794   2020-01-26                100.0                t
# 24795   2020-01-25                100.0                t
# 24797   2020-01-23                100.0                t
# 24798   2020-01-24                100.0                t
# 24818   2020-01-23                100.0                t
# 24898   2020-01-27                100.0                t
#
#                cancellation_policy  require_guest_profile_picture  \
# 0                         moderate                              f
# 1                         moderate                              f
# 4                         moderate                              f
# 5      strict_14_with_grace_period                              f
# 6      strict_14_with_grace_period                              f
# 7      strict_14_with_grace_period                              t
# 8      strict_14_with_grace_period                              f
# 9                         moderate                              f
# 10                        flexible                              f
# 11                        flexible                              f
# 16     strict_14_with_grace_period                              f
# 18                        flexible                              f
# 19                        moderate                              f
# 20                        moderate                              f
# 21     strict_14_with_grace_period                              f
# 22     strict_14_with_grace_period                              t
# 23     strict_14_with_grace_period                              f
# 25     strict_14_with_grace_period                              f
# 26     strict_14_with_grace_period                              f
# 27     strict_14_with_grace_period                              f
# 28     strict_14_with_grace_period                              f
# 29                        flexible                              f
# 30     strict_14_with_grace_period                              f
# 31     strict_14_with_grace_period                              f
# 32     strict_14_with_grace_period                              f
# 33     strict_14_with_grace_period                              f
# 34     strict_14_with_grace_period                              f
# 35     strict_14_with_grace_period                              f
# 39                        moderate                              f
# 42                        moderate                              f
# ...                            ...                            ...
# 24607                     flexible                              f
# 24608                     moderate                              f
# 24610                     moderate                              f
# 24625                     flexible                              f
# 24626  strict_14_with_grace_period                              f
# 24638  strict_14_with_grace_period                              f
# 24641  strict_14_with_grace_period                              f
# 24644  strict_14_with_grace_period                              f
# 24645                     flexible                              f
# 24648                     flexible                              t
# 24657                     moderate                              f
# 24703                     flexible                              f
# 24712  strict_14_with_grace_period                              f
# 24715  strict_14_with_grace_period                              f
# 24721  strict_14_with_grace_period                              f
# 24724  strict_14_with_grace_period                              f
# 24725  strict_14_with_grace_period                              f
# 24732                     moderate                              f
# 24739  strict_14_with_grace_period                              f
# 24740                     moderate                              f
# 24744                     moderate                              f
# 24745                     flexible                              f
# 24761                     moderate                              f
# 24793  strict_14_with_grace_period                              f
# 24794  strict_14_with_grace_period                              f
# 24795  strict_14_with_grace_period                              f
# 24797  strict_14_with_grace_period                              f
# 24798  strict_14_with_grace_period                              f
# 24818                     flexible                              f
# 24898                     moderate                              f
#
#        require_guest_phone_verification  calculated_host_listings_count  \
# 0                                     f                               1
# 1                                     f                               1
# 4                                     f                               1
# 5                                     t                               2
# 6                                     t                               2
# 7                                     t                               1
# 8                                     f                               2
# 9                                     f                              15
# 10                                    f                               9
# 11                                    f                               5
# 16                                    f                               2
# 18                                    f                               2
# 19                                    f                               8
# 20                                    f                               1
# 21                                    f                               7
# 22                                    t                               7
# 23                                    f                               7
# 25                                    f                               2
# 26                                    f                              25
# 27                                    t                               1
# 28                                    f                               1
# 29                                    f                               1
# 30                                    f                               1
# 31                                    f                               7
# 32                                    f                               1
# 33                                    t                               1
# 34                                    f                              10
# 35                                    f                              10
# 39                                    f                               4
# 42                                    t                               9
# ...                                 ...                             ...
# 24607                                 f                              10
# 24608                                 f                              10
# 24610                                 f                              32
# 24625                                 f                               1
# 24626                                 f                               1
# 24638                                 f                               4
# 24641                                 f                              45
# 24644                                 f                               1
# 24645                                 f                               2
# 24648                                 t                               3
# 24657                                 f                               5
# 24703                                 f                               5
# 24712                                 f                              45
# 24715                                 f                              45
# 24721                                 f                              45
# 24724                                 f                              45
# 24725                                 f                              45
# 24732                                 f                               2
# 24739                                 f                               1
# 24740                                 f                               4
# 24744                                 f                              30
# 24745                                 f                               1
# 24761                                 f                               2
# 24793                                 f                              45
# 24794                                 f                              45
# 24795                                 f                              45
# 24797                                 f                              45
# 24798                                 f                              45
# 24818                                 f                               1
# 24898                                 f                               3
#
#       reviews_per_month
# 0                  0.39
# 1                  1.61
# 4                  2.89
# 5                  2.48
# 6                  0.47
# 7                  0.32
# 8                  0.02
# 9                  3.25
# 10                 1.12
# 11                 0.16
# 16                 0.37
# 18                 0.09
# 19                 1.27
# 20                 0.50
# 21                 0.24
# 22                 0.56
# 23                 0.19
# 25                 2.06
# 26                 0.75
# 27                 1.70
# 28                 0.86
# 29                 0.34
# 30                 0.27
# 31                 0.17
# 32                 0.87
# 33                 0.81
# 34                 0.39
# 35                 1.34
# 39                 1.25
# 42                 2.15
# ...                 ...
# 24607              5.00
# 24608              2.00
# 24610              1.00
# 24625              1.00
# 24626              1.00
# 24638              1.00
# 24641              1.00
# 24644              1.00
# 24645              2.00
# 24648              2.00
# 24657              1.00
# 24703              1.00
# 24712              1.00
# 24715              1.00
# 24721              2.00
# 24724              1.00
# 24725              1.00
# 24732              4.00
# 24739              4.00
# 24740              1.00
# 24744              1.00
# 24745              2.00
# 24761              1.00
# 24793              2.00
# 24794              1.00
# 24795              3.00
# 24797              1.00
# 24798              2.00
# 24818              1.00
# 24898              1.00
#
# [15733 rows x 28 columns]

# %%
data.shape
# Out:
# (15733, 28)

# %%
data['review_scores_rating']
# Out:
# 0         91.0
# 1         96.0
# 4         91.0
# 5         96.0
# 6         98.0
# 7         93.0
# 8        100.0
# 9         88.0
# 10        88.0
# 11        84.0
# 16        90.0
# 18       100.0
# 19        92.0
# 20        96.0
# 21        92.0
# 22        92.0
# 23        87.0
# 25        88.0
# 26        92.0
# 27        99.0
# 28        95.0
# 29        94.0
# 30        95.0
# 31        88.0
# 32        90.0
# 33        94.0
# 34        83.0
# 35        96.0
# 39        98.0
# 42        97.0
#          ...
# 24607     92.0
# 24608     80.0
# 24610    100.0
# 24625    100.0
# 24626     80.0
# 24638     60.0
# 24641    100.0
# 24644    100.0
# 24645    100.0
# 24648    100.0
# 24657      NaN
# 24703    100.0
# 24712    100.0
# 24715    100.0
# 24721     90.0
# 24724    100.0
# 24725    100.0
# 24732     95.0
# 24739     90.0
# 24740     80.0
# 24744    100.0
# 24745    100.0
# 24761    100.0
# 24793    100.0
# 24794    100.0
# 24795    100.0
# 24797    100.0
# 24798    100.0
# 24818    100.0
# 24898    100.0
# Name: review_scores_rating, Length: 15733, dtype: float64

# %%
#let's check datatypes
data.dtypes
# Out:
# id                                    int64
# name                                 object
# description                          object
# neighborhood_overview                object
# host_is_superhost                    object
# neighbourhood_cleansed               object
# neighbourhood_group_cleansed         object
# property_type                        object
# room_type                            object
# accommodates                          int64
# bathrooms                           float64
# bedrooms                            float64
# beds                                float64
# bed_type                             object
# amenities                            object
# price                                object
# guests_included                       int64
# minimum_nights                        int64
# number_of_reviews                     int64
# first_review                         object
# last_review                          object
# review_scores_rating                float64
# instant_bookable                     object
# cancellation_policy                  object
# require_guest_profile_picture        object
# require_guest_phone_verification     object
# calculated_host_listings_count        int64
# reviews_per_month                   float64
# dtype: object

# %%
data['price']
# Out:
# 0           $40.00
# 1           $60.00
# 4           $60.00
# 5           $60.00
# 6        $1,000.00
# 7           $45.00
# 8           $40.00
# 9           $70.00
# 10          $50.00
# 11          $65.00
# 16          $60.00
# 18          $69.00
# 19          $40.00
# 20          $80.00
# 21          $90.00
# 22          $70.00
# 23          $85.00
# 25          $80.00
# 26          $92.00
# 27         $105.00
# 28          $65.00
# 29          $75.00
# 30         $125.00
# 31         $145.00
# 32          $50.00
# 33          $90.00
# 34          $22.00
# 35          $80.00
# 39          $26.00
# 42          $48.00
#            ...
# 24607       $45.00
# 24608       $45.00
# 24610      $148.00
# 24625      $150.00
# 24626       $40.00
# 24638       $40.00
# 24641       $45.00
# 24644      $110.00
# 24645      $120.00
# 24648       $20.00
# 24657       $37.00
# 24703       $69.00
# 24712       $65.00
# 24715       $50.00
# 24721       $50.00
# 24724       $50.00
# 24725       $45.00
# 24732       $80.00
# 24739      $359.00
# 24740       $35.00
# 24744      $146.00
# 24745       $20.00
# 24761       $32.00
# 24793       $60.00
# 24794       $65.00
# 24795      $100.00
# 24797       $80.00
# 24798       $80.00
# 24818       $50.00
# 24898       $50.00
# Name: price, Length: 15733, dtype: object

# %%
#let's change price type from object to float
# but first we neeed to remove special characters --> $ symbol
data['price'] = data['price'].str.replace('$', '')
data['price'] = data['price'].str.replace(',', '')

data['price'] = data.price.astype(float)

data['price'].dtypes #sucess!
# Out:
# dtype('float64')

# %%
#also it does not make sense to have data points with price zero
price_zero = data[(data['price']==0)]
price_zero
# Out:
#              id                                    name  \
# 11174  20385175  Mouraria Apartments in Beco de SM (II)
# 11201  20436203      Elegant Flat with a Beautiful View
# 11202  20436797       Spacious Apartment near the River
# 11323  20613763                     Double Bed Room I04
# 11375  20690078                     Double Bed Room N04
#
#                                              description  \
# 11174  If you are looking for a place to live during ...
# 11201  Elegant apartment with a beautiful view,  idea...
# 11202  This is an apartment with much light for a gro...
# 11323  Private room with a double bed in a shared apa...
# 11375  Private room with a double bed in a shared apa...
#
#                                    neighborhood_overview host_is_superhost  \
# 11174  If you are looking for a place to live during ...                 f
# 11201  LX Factory It’s in the year 1846 that a thread...                 f
# 11202  LX Factory It’s in the year 1846 that a thread...                 f
# 11323                                                NaN                 f
# 11375  Student’s home is located in Lisboa, Portugal....                 f
#
#       neighbourhood_cleansed neighbourhood_group_cleansed property_type  \
# 11174      Santa Maria Maior                       Lisboa     Apartment
# 11201               Alcntara                       Lisboa     Apartment
# 11202               Alcntara                       Lisboa     Apartment
# 11323                Arroios                       Lisboa     Apartment
# 11375                Arroios                       Lisboa     Apartment
#
#              room_type  accommodates  ...  number_of_reviews  first_review  \
# 11174  Entire home/apt             2  ...                 26    2017-08-17
# 11201  Entire home/apt             4  ...                 26    2017-10-16
# 11202  Entire home/apt             4  ...                  8    2017-09-17
# 11323     Private room             2  ...                  1    2017-08-28
# 11375     Private room             2  ...                  2    2017-09-06
#
#        last_review review_scores_rating instant_bookable  \
# 11174   2019-09-30                 76.0                t
# 11201   2020-01-03                 93.0                t
# 11202   2019-09-28                 88.0                t
# 11323   2017-08-28                 40.0                f
# 11375   2017-09-08                 70.0                f
#
#                cancellation_policy  require_guest_profile_picture  \
# 11174  strict_14_with_grace_period                              f
# 11201                     moderate                              f
# 11202                     moderate                              f
# 11323                     flexible                              f
# 11375                     flexible                              f
#
#        require_guest_phone_verification  calculated_host_listings_count  \
# 11174                                 f                              14
# 11201                                 f                               6
# 11202                                 f                               6
# 11323                                 f                              10
# 11375                                 f                              10
#
#       reviews_per_month
# 11174              0.87
# 11201              0.93
# 11202              0.28
# 11323              0.03
# 11375              0.07
#
# [5 rows x 28 columns]

# %%
## remove those rows

data = data.drop([11174,11201,11202,11323,11375], axis=0)

# %%
price_zero = data[(data['price']==0)]
price_zero
# Out:
# Empty DataFrame
# Columns: [id, name, description, neighborhood_overview, host_is_superhost, neighbourhood_cleansed, neighbourhood_group_cleansed, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, price, guests_included, minimum_nights, number_of_reviews, first_review, last_review, review_scores_rating, instant_bookable, cancellation_policy, require_guest_profile_picture, require_guest_phone_verification, calculated_host_listings_count, reviews_per_month]
# Index: []
#
# [0 rows x 28 columns]

# %%
#convert fist and last review into data type data format

data['last_review'] = pd.to_datetime(data['last_review'])
data['first_review'] = pd.to_datetime(data['first_review'])

# %%
# listing_duration = (last_review - first_review) -> value to be evaluated in days

data.insert(21, "listing_duration", data['last_review'] - data["first_review"], True)

# %%
data['listing_duration'].unique()
# Out:
# array([168393600000000000, 177465600000000000, 278467200000000000, ...,
#         13996800000000000,   8467200000000000,   9936000000000000],
#       dtype='timedelta64[ns]')

# %%
#transform into days
data["listing_duration"]=  (data['last_review'] - data["first_review"]).dt.days
data['listing_duration'].unique()
# Out:
# array([1949, 2054, 3223, ...,  162,   98,  115], dtype=int64)

# %%
data.dtypes
# Out:
# id                                           int64
# name                                        object
# description                                 object
# neighborhood_overview                       object
# host_is_superhost                           object
# neighbourhood_cleansed                      object
# neighbourhood_group_cleansed                object
# property_type                               object
# room_type                                   object
# accommodates                                 int64
# bathrooms                                  float64
# bedrooms                                   float64
# beds                                       float64
# bed_type                                    object
# amenities                                   object
# price                                      float64
# guests_included                              int64
# minimum_nights                               int64
# number_of_reviews                            int64
# first_review                        datetime64[ns]
# last_review                         datetime64[ns]
# listing_duration                             int64
# review_scores_rating                       float64
# instant_bookable                            object
# cancellation_policy                         object
# require_guest_profile_picture               object
# require_guest_phone_verification            object
# calculated_host_listings_count               int64
# reviews_per_month                          float64
# dtype: object

# %% [markdown]
# # TO DO:

# %%
"""
We'll use 'instant_bookable', 'cancellation_policy', 'require_guest_profile_picture' and 'require_guest_phone_verification'
to a create a single varible where we can analyse the flexibility of the listing. 
"""

data['cancellation_policy'].unique()
# Out:
# array(['moderate', 'strict_14_with_grace_period', 'flexible',
#        'super_strict_60', 'super_strict_30', 'strict'], dtype=object)

# %%
#rename columns 
data = data.rename(columns={'neighbourhood_cleansed':'neighbourhood',
                            'neighbourhood_group_cleansed':'city'})

# %%
print(data.columns.tolist())
# Out:
# ['id', 'name', 'description', 'neighborhood_overview', 'host_is_superhost', 'neighbourhood', 'city', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price', 'guests_included', 'minimum_nights', 'number_of_reviews', 'first_review', 'last_review', 'listing_duration', 'review_scores_rating', 'instant_bookable', 'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification', 'calculated_host_listings_count', 'reviews_per_month']

# %%
## order columns 

column_order = ['id', 'name', 'city','neighbourhood', 'price','description', 'neighborhood_overview',   
                'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 
                'amenities',  'guests_included', 'minimum_nights', 'number_of_reviews', 'first_review', 'last_review',
                'listing_duration', 'review_scores_rating', 'host_is_superhost','instant_bookable', 'cancellation_policy', 
                'require_guest_profile_picture', 'require_guest_phone_verification', 'calculated_host_listings_count', 
                'reviews_per_month']

data = data[column_order]
data.head()
# Out:
#       id                                       name    city  \
# 0   6499       Belém 1 Bedroom Historical Apartment  Lisboa
# 1  25659  Sunny,  Alfama  Sleeps 3 - Coeur d'Alfama  Lisboa
# 4  29248   Apartamento Alfama com vista para o rio!  Lisboa
# 5  29396           Alfama Hill - Boutique apartment  Lisboa
# 6  29720                TheHOUSE - Your luxury home  Lisboa
#
#        neighbourhood   price  \
# 0               Belm    40.0
# 1  Santa Maria Maior    60.0
# 4  Santa Maria Maior    60.0
# 5  Santa Maria Maior    60.0
# 6            Estrela  1000.0
#
#                                          description  \
# 0  This apartment is all about Location, next to ...
# 1  Sunny 1 Bedroom cozy apartment in historic Alf...
# 4  Located in the city center, and great location...
# 5  Feel at home in the historic centre of Lisbon....
# 6  A house at the top of an anonimous building, T...
#
#                                neighborhood_overview property_type  \
# 0  To get  to the city center, tram 15 stops in f...     Apartment
# 1  Alfama is the oldest and most picturesque quar...     Apartment
# 4                                                NaN     Apartment
# 5  Great neighborhood in the old part of town. Am...     Apartment
# 6  Location in the city's Embassies area, near en...     Apartment
#
#          room_type  accommodates  ...  last_review  listing_duration  \
# 0  Entire home/apt             3  ...   2020-01-03              1949
# 1  Entire home/apt             3  ...   2019-12-08              2054
# 4  Entire home/apt             4  ...   2019-10-29              3223
# 5  Entire home/apt             4  ...   2020-01-12              2791
# 6  Entire home/apt            16  ...   2020-01-03              3285
#
#    review_scores_rating host_is_superhost instant_bookable  \
# 0                  91.0                 f                t
# 1                  96.0                 t                t
# 4                  91.0                 f                t
# 5                  96.0                 f                t
# 6                  98.0                 t                f
#
#            cancellation_policy  require_guest_profile_picture  \
# 0                     moderate                              f
# 1                     moderate                              f
# 4                     moderate                              f
# 5  strict_14_with_grace_period                              f
# 6  strict_14_with_grace_period                              f
#
#    require_guest_phone_verification calculated_host_listings_count  \
# 0                                 f                              1
# 1                                 f                              1
# 4                                 f                              1
# 5                                 t                              2
# 6                                 t                              2
#
#   reviews_per_month
# 0              0.39
# 1              1.61
# 4              2.89
# 5              2.48
# 6              0.47
#
# [5 rows x 29 columns]

# %%
#create a flexibility variable with 'require_guest_profile_picture', 'require_guest_phone_verification','instant_bookable'

### labels = ['Low Flexibility', 'Moderate', 'High Flexibility']

# %% [markdown]
# # A Neighborhood Analysis

# %%
data['neighbourhood'].unique()
# Out:
# array(['Belm', 'Santa Maria Maior', 'Estrela', 'Avenidas Novas', 'Lumiar',
#        'Misericrdia', 'So Vicente', 'Campolide', 'Santo Antnio',
#        'Alvalade', 'Penha de Frana', 'Arroios', 'Alcntara', 'Areeiro',
#        'Ajuda', 'Parque das Naes', 'Campo de Ourique', 'Benfica',
#        'Olivais', 'So Domingos de Benfica', 'Beato', 'Marvila', 'Carnide',
#        'Santa Clara'], dtype=object)

# %%
data.groupby(['neighbourhood'])

# %%
#### PRICE ANALYSIS ####
neighbourhood_price = data.groupby(['neighbourhood'])['price'].describe().reset_index()
neighbourhood_price.head()
neighbourhood_price.columns
neighbourhood_price.sort_values(['mean'], ascending = False)
# Média mais barata é Beato
# Média mais cara é Parque das Nações
# Maior variação de preços em Marvila, Lumiar, Santa Maria Maior, Santa Clara e Arroios
# Out:
#              neighbourhood   count        mean         std   min    25%   50%  \
# 17         Parque das Naes   305.0  100.045902   67.038367  20.0  60.00  86.0
# 13                  Lumiar   127.0   91.543307  155.857931  13.0  35.00  50.0
# 20       Santa Maria Maior  3391.0   90.173400  154.347860   9.0  50.00  72.0
# 15             Misericrdia  2786.0   87.562455   74.084370  12.0  50.00  70.0
# 21            Santo Antnio  1292.0   87.094427   65.751336  10.0  50.00  72.5
# 14                 Marvila    70.0   84.371429  173.313921  12.0  39.00  55.0
# 5           Avenidas Novas   613.0   82.223491   83.697580   9.0  40.00  59.0
# 23              So Vicente  1350.0   79.109630   68.732018  12.0  49.25  65.0
# 12                 Estrela   993.0   77.415911   64.610068  14.0  47.00  60.0
# 4                  Arroios  1979.0   76.529055   94.412935   9.0  39.00  59.0
# 0                    Ajuda   168.0   75.696429   93.843912  18.0  41.75  55.5
# 9         Campo de Ourique   323.0   73.842105   60.619036   8.0  44.50  60.0
# 7                     Belm   307.0   70.980456   45.031938  13.0  49.00  62.0
# 22  So Domingos de Benfica   123.0   70.569106   42.168686   9.0  39.00  60.0
# 1                 Alcntara   288.0   69.927083   57.234327  15.0  40.00  55.0
# 2                 Alvalade   225.0   69.426667   90.608780  11.0  35.00  50.0
# 10               Campolide   165.0   66.618182   63.200173   9.0  35.00  55.0
# 19             Santa Clara    18.0   65.555556  136.782017   9.0  17.75  20.5
# 3                  Areeiro   330.0   61.009091   50.733614  11.0  30.00  49.0
# 8                  Benfica    57.0   58.543860   29.634723  14.0  40.00  55.0
# 11                 Carnide    40.0   58.175000   45.664825   9.0  35.00  50.0
# 18          Penha de Frana   521.0   56.763916   33.865968   9.0  32.00  50.0
# 16                 Olivais   176.0   55.301136   37.940633  11.0  30.00  49.0
# 6                    Beato    81.0   52.679012   26.076247  10.0  35.00  50.0
#
#       75%     max
# 17  123.0   500.0
# 13   84.0  1000.0
# 20  100.0  8000.0
# 15  100.0  1000.0
# 21  100.0  1100.0
# 14   75.0  1400.0
# 5    99.0  1200.0
# 23   85.0   950.0
# 12   90.0  1000.0
# 4    85.5  2300.0
# 0    78.5  1000.0
# 9    90.0   800.0
# 7    80.0   500.0
# 22   94.0   250.0
# 1    80.0   700.0
# 2    80.0  1167.0
# 10   79.0   712.0
# 19   47.5   600.0
# 3    70.0   400.0
# 8    70.0   165.0
# 11   66.0   300.0
# 18   75.0   250.0
# 16   70.0   385.0
# 6    69.0   137.0

# %%
# what neighbourhoods have oldest listings --> this can provide insight on the most habitual touristic areas
neighbourhood_duration = data.groupby(['neighbourhood'])['listing_duration'].describe()
neighbourhood_duration.sort_values(by=['max'], ascending=False)
# Traditional Airbnb Neighbourhoods = Avenidas Novas, Misericordia, Estrela, São Vicente e Santa Maria Maior
# disponíveis há mais de 9 anos
# Out:
#                          count        mean         std  min     25%    50%  \
# neighbourhood
# Avenidas Novas           613.0  618.946166  590.303862  0.0   52.00  497.0
# Misericrdia             2786.0  917.089017  709.839051  0.0  337.25  814.5
# Estrela                  993.0  711.083585  637.236736  0.0  188.00  538.0
# So Vicente              1350.0  769.329630  625.248390  0.0  263.50  609.5
# Santa Maria Maior       3391.0  928.209378  715.014851  0.0  335.00  793.0
# Santo Antnio            1292.0  740.773220  647.463044  0.0  215.00  570.0
# Alcntara                 288.0  579.781250  540.535163  0.0  181.50  441.5
# Alvalade                 225.0  716.893333  595.085128  0.0  207.00  577.0
# Arroios                 1979.0  656.563921  591.260493  0.0  185.00  495.0
# Penha de Frana           521.0  544.664107  511.925788  0.0  153.00  414.0
# Campolide                165.0  542.878788  577.872979  0.0  127.00  394.0
# Campo de Ourique         323.0  652.529412  544.645900  0.0  170.50  561.0
# Belm                     307.0  636.726384  568.316005  0.0  147.00  481.0
# Areeiro                  330.0  545.727273  516.903151  0.0   84.25  444.5
# Ajuda                    168.0  647.791667  570.364658  0.0  209.00  515.0
# Benfica                   57.0  611.736842  561.168122  0.0  198.00  481.0
# Olivais                  176.0  547.579545  525.784534  0.0  125.50  412.5
# So Domingos de Benfica   123.0  500.463415  535.546317  0.0   37.50  356.0
# Lumiar                   127.0  479.826772  548.172666  0.0   17.50  349.0
# Parque das Naes          305.0  586.970492  508.539306  0.0  148.00  494.0
# Beato                     81.0  674.950617  561.247648  0.0  200.00  511.0
# Marvila                   70.0  464.057143  472.372516  0.0   66.25  370.5
# Carnide                   40.0  389.200000  432.337961  0.0   95.50  239.5
# Santa Clara               18.0  324.277778  352.971388  0.0    1.75  179.0
#
#                             75%     max
# neighbourhood
# Avenidas Novas          1003.00  3468.0
# Misericrdia             1355.00  3291.0
# Estrela                 1117.00  3285.0
# So Vicente              1157.75  3260.0
# Santa Maria Maior       1392.50  3223.0
# Santo Antnio            1104.00  3127.0
# Alcntara                 856.75  3092.0
# Alvalade                1135.00  3066.0
# Arroios                  999.50  2994.0
# Penha de Frana           823.00  2966.0
# Campolide                803.00  2853.0
# Campo de Ourique         968.50  2735.0
# Belm                     982.00  2617.0
# Areeiro                  862.25  2604.0
# Ajuda                    915.50  2528.0
# Benfica                  814.00  2477.0
# Olivais                  847.00  2430.0
# So Domingos de Benfica   773.50  2320.0
# Lumiar                   799.00  2315.0
# Parque das Naes          896.00  2279.0
# Beato                   1218.00  2199.0
# Marvila                  769.00  1987.0
# Carnide                  514.00  1838.0
# Santa Clara              528.75  1111.0

# %%
## which neighbourhoods have best ratings from costumers???
neighbourhood_reviews = data.groupby(['neighbourhood'])['review_scores_rating'].describe()
neighbourhood_reviews.sort_values(by=['mean'], ascending = False)
# Out:
#                          count       mean        std   min    25%   50%  \
# neighbourhood
# Santa Clara               17.0  96.588235   3.906066  87.0  95.00  97.0
# Alvalade                 224.0  93.508929   7.833463  20.0  91.00  95.0
# Olivais                  174.0  93.264368   8.486589  20.0  91.00  95.0
# Parque das Naes          298.0  93.137584   8.917006  20.0  92.00  96.0
# So Vicente              1338.0  92.982810   6.597783  40.0  90.00  94.0
# Alcntara                 285.0  92.852632   7.012517  55.0  90.00  94.0
# Ajuda                    168.0  92.779762   7.641226  40.0  90.00  95.0
# Campo de Ourique         320.0  92.687500   8.427219  40.0  90.00  95.0
# Carnide                   38.0  92.605263   8.845642  60.0  88.25  95.0
# So Domingos de Benfica   120.0  92.475000   8.742788  60.0  88.00  95.0
# Lumiar                   124.0  92.346774  10.661110  40.0  90.00  96.5
# Benfica                   57.0  92.315789  10.576520  40.0  90.00  96.0
# Santa Maria Maior       3378.0  92.260213   7.561617  20.0  90.00  94.0
# Areeiro                  325.0  92.233846   9.575275  20.0  90.00  94.0
# Marvila                   69.0  92.014493  12.958636  20.0  90.00  96.0
# Belm                     306.0  91.977124  11.325706  20.0  90.00  95.0
# Santo Antnio            1283.0  91.855027   8.846544  20.0  89.00  94.0
# Misericrdia             2770.0  91.782671   8.157690  20.0  89.00  94.0
# Estrela                  987.0  91.746707   8.573077  20.0  90.00  93.0
# Avenidas Novas           607.0  91.693575   9.977616  20.0  89.00  95.0
# Penha de Frana           517.0  91.560928   9.319203  20.0  89.00  94.0
# Campolide                160.0  91.525000  10.033873  20.0  88.75  93.5
# Arroios                 1960.0  90.964286   9.662701  20.0  88.00  93.0
# Beato                     80.0  89.550000   8.878790  60.0  85.00  91.0
#
#                           75%    max
# neighbourhood
# Santa Clara             100.0  100.0
# Alvalade                 98.0  100.0
# Olivais                  99.0  100.0
# Parque das Naes          99.0  100.0
# So Vicente               97.0  100.0
# Alcntara                 98.0  100.0
# Ajuda                    97.0  100.0
# Campo de Ourique         98.0  100.0
# Carnide                 100.0  100.0
# So Domingos de Benfica  100.0  100.0
# Lumiar                  100.0  100.0
# Benfica                  98.0  100.0
# Santa Maria Maior        97.0  100.0
# Areeiro                  98.0  100.0
# Marvila                 100.0  100.0
# Belm                     98.0  100.0
# Santo Antnio             98.0  100.0
# Misericrdia              97.0  100.0
# Estrela                  97.0  100.0
# Avenidas Novas           98.0  100.0
# Penha de Frana           97.0  100.0
# Campolide                98.0  100.0
# Arroios                  97.0  100.0
# Beato                    97.0  100.0

# %%
## If i want to come to lisbon of a short weekend which neighbourhood would be easier? (e.g. would have less min nights)

neighbourhood_minimum_nights = data.groupby(['neighbourhood'])['minimum_nights'].describe()
neighbourhood_minimum_nights.sort_values(by=['mean'], ascending = True)
# Out:
#                          count      mean        std  min  25%  50%   75%  \
# neighbourhood
# Santa Maria Maior       3391.0  2.225597   2.302904  1.0  2.0  2.0  3.00
# Ajuda                    168.0  2.297619   1.833029  1.0  2.0  2.0  3.00
# Alcntara                 288.0  2.312500   1.803862  1.0  2.0  2.0  3.00
# Misericrdia             2786.0  2.383345   6.094545  1.0  2.0  2.0  3.00
# Areeiro                  330.0  2.403030   2.702806  1.0  1.0  2.0  3.00
# Estrela                  993.0  2.411883   3.370373  1.0  2.0  2.0  3.00
# So Vicente              1350.0  2.417037   1.799062  1.0  2.0  2.0  3.00
# Beato                     81.0  2.444444   2.454588  1.0  2.0  2.0  3.00
# Campo de Ourique         323.0  2.461300   1.941910  1.0  2.0  2.0  3.00
# Parque das Naes          305.0  2.478689   2.980259  1.0  1.0  2.0  3.00
# Lumiar                   127.0  2.559055   2.885799  1.0  1.0  2.0  3.00
# Benfica                   57.0  2.578947   2.419765  1.0  1.0  2.0  3.00
# Arroios                 1979.0  2.643254   5.451141  1.0  1.0  2.0  3.00
# So Domingos de Benfica   123.0  2.658537   2.666825  1.0  1.0  2.0  3.00
# Santo Antnio            1292.0  2.726006  10.731531  1.0  1.0  2.0  3.00
# Penha de Frana           521.0  2.896353  13.248396  1.0  2.0  2.0  3.00
# Avenidas Novas           613.0  3.006525   7.745120  1.0  1.0  2.0  3.00
# Belm                     307.0  3.104235   9.915767  1.0  1.0  2.0  3.00
# Olivais                  176.0  3.170455  15.126682  1.0  1.0  1.0  2.00
# Campolide                165.0  3.296970   5.089713  1.0  1.0  2.0  3.00
# Marvila                   70.0  3.500000  10.579924  1.0  1.0  2.0  3.00
# Alvalade                 225.0  4.315556  17.003229  1.0  1.0  2.0  3.00
# Carnide                   40.0  4.575000   7.652342  1.0  2.0  2.0  3.00
# Santa Clara               18.0  6.666667  10.792154  1.0  1.0  2.0  3.75
#
#                           max
# neighbourhood
# Santa Maria Maior        80.0
# Ajuda                    20.0
# Alcntara                 20.0
# Misericrdia             300.0
# Areeiro                  30.0
# Estrela                  90.0
# So Vicente               30.0
# Beato                    20.0
# Campo de Ourique         21.0
# Parque das Naes          30.0
# Lumiar                   30.0
# Benfica                  14.0
# Arroios                 120.0
# So Domingos de Benfica   15.0
# Santo Antnio            365.0
# Penha de Frana          300.0
# Avenidas Novas           90.0
# Belm                    120.0
# Olivais                 200.0
# Campolide                30.0
# Marvila                  90.0
# Alvalade                180.0
# Carnide                  30.0
# Santa Clara              30.0

# %%
data['price'].describe()
# Out:
# count    15728.000000
# mean        81.394138
# std         98.036960
# min          8.000000
# 25%         45.000000
# 50%         65.000000
# 75%         95.000000
# max       8000.000000
# Name: price, dtype: float64

# %%
#### VALUE FOR MONEY #######

# value_money = review_scores_rating/price

data.insert(5, "value_money", data["review_scores_rating"]/data['price'], True)

# %%
neighbourhood_value_money = data.groupby(['neighbourhood'])['value_money'].describe()
neighbourhood_value_money.sort_values(by=['mean'], ascending=False)
# Out:
#                          count      mean       std       min       25%  \
# neighbourhood
# Santa Clara               17.0  4.675917  2.915218  0.156667  2.475000
# Areeiro                  325.0  2.355607  1.639764  0.316667  1.276316
# Olivais                  174.0  2.305395  1.382242  0.259740  1.346154
# Beato                     80.0  2.239341  1.345456  0.640000  1.389312
# Penha de Frana           517.0  2.215976  1.404766  0.200000  1.250000
# Alvalade                 224.0  2.178612  1.447092  0.082262  1.200000
# Carnide                   38.0  2.140977  1.526354  0.323333  1.427536
# Marvila                   69.0  2.131546  1.464272  0.057143  1.282051
# Campolide                160.0  2.068875  1.590476  0.500000  1.159855
# Benfica                   57.0  1.972608  1.022854  0.551515  1.280000
# Lumiar                   124.0  1.941908  1.230555  0.095000  1.084465
# Arroios                 1960.0  1.889999  1.242345  0.042174  1.061875
# So Domingos de Benfica   120.0  1.870858  1.316021  0.400000  0.980294
# Campo de Ourique         320.0  1.870112  1.440100  0.122500  1.010420
# Alcntara                 285.0  1.859996  1.097015  0.142857  1.123596
# Avenidas Novas           607.0  1.856248  1.417899  0.083333  0.960000
# Ajuda                    168.0  1.841071  1.011627  0.080000  1.184743
# Belm                     306.0  1.699734  1.053020  0.180000  1.128411
# Estrela                  987.0  1.640109  0.951067  0.098000  1.022100
# So Vicente              1338.0  1.608294  0.881334  0.103158  1.078652
# Santo Antnio            1283.0  1.497327  0.946971  0.077273  0.900000
# Santa Maria Maior       3378.0  1.437867  0.867891  0.012500  0.910000
# Misericrdia             2770.0  1.427229  0.796267  0.070000  0.928752
# Parque das Naes          298.0  1.308997  0.852978  0.166667  0.769231
#
#                              50%       75%        max
# neighbourhood
# Santa Clara             4.700000  5.882353  10.777778
# Areeiro                 1.904762  3.000000   8.909091
# Olivais                 1.960000  2.890517   8.333333
# Beato                   1.760482  2.705462   8.000000
# Penha de Frana          1.800000  2.800000  10.444444
# Alvalade                1.712069  2.750000   8.363636
# Carnide                 1.696970  2.778571   9.888889
# Marvila                 1.666667  2.538462   7.500000
# Campolide               1.625000  2.500000  10.555556
# Benfica                 1.666667  2.285714   5.388889
# Lumiar                  1.600000  2.564103   6.666667
# Arroios                 1.546921  2.350735   8.700000
# So Domingos de Benfica  1.519231  2.425000  10.000000
# Campo de Ourique        1.512571  2.090104  12.500000
# Alcntara                1.672414  2.285714   6.666667
# Avenidas Novas          1.474576  2.250000  11.111111
# Ajuda                   1.616667  2.161111   5.555556
# Belm                    1.473756  1.939694   7.000000
# Estrela                 1.500000  1.955556   6.785714
# So Vicente              1.450000  1.900000   8.000000
# Santo Antnio            1.266667  1.820000   7.076923
# Santa Maria Maior       1.279706  1.759259  10.333333
# Misericrdia             1.277047  1.745455   7.384615
# Parque das Naes         1.114379  1.583333   5.000000

# %% [markdown]
# Santa Clara seems to be the most value for money

# %%
# Room Type|Price
room_price = data.groupby(['room_type'])['price'].describe().reset_index()
room_price.sort_values(by=['mean'])
# Out:
#          room_type    count        mean         std   min   25%   50%    75%  \
# 3      Shared room    170.0   18.735294    8.897539   9.0  13.0  16.0   20.0
# 2     Private room   3171.0   43.177547   46.490103   8.0  25.0  35.0   50.0
# 0  Entire home/apt  12108.0   91.108854  102.276753   9.0  55.0  75.0  100.0
# 1       Hotel room    279.0  132.329749  194.162245  13.0  50.0  76.0  140.0
#
#       max
# 3    60.0
# 2  1500.0
# 0  8000.0
# 1  1500.0

# %%
# Group by neighbourhood and type of place
neighbourhood_rooms = data.groupby(['room_type','neighbourhood'])['price'].agg(['mean', 'median'])
neighbourhood_rooms
neighbourhood_rooms.sort_values(by=['room_type','mean'], ascending= True)
# Out:
#                                               mean  median
# room_type       neighbourhood
# Entire home/apt Beato                    61.051724    50.5
#                 Carnide                  70.666667    60.0
#                 Benfica                  71.764706    62.5
#                 Penha de Frana           71.882353    65.0
#                 Olivais                  72.558442    60.0
#                 Belm                     76.784232    65.0
#                 Alcntara                 79.421525    69.0
#                 Ajuda                    84.057143    60.0
#                 Campolide                84.409524    70.0
#                 So Vicente               84.545455    69.0
#                 Campo de Ourique         85.272000    70.0
#                 Estrela                  86.063910    69.0
#                 So Domingos de Benfica   86.625000    75.0
#                 Misericrdia              91.805958    75.0
#                 Santa Maria Maior        92.943597    75.0
#                 Arroios                  93.327332    75.0
#                 Areeiro                  94.331034    75.0
#                 Alvalade                 95.238462    70.0
#                 Santo Antnio             99.262564    80.0
#                 Lumiar                   99.878049    70.0
#                 Parque das Naes         109.250000    95.0
#                 Avenidas Novas          112.951557    85.0
#                 Marvila                 113.477273    68.0
#                 Santa Clara             179.600000    90.0
# Hotel room      Estrela                  50.777778    30.0
#                 Campo de Ourique         51.000000    50.0
#                 Alvalade                 51.200000    50.0
#                 Penha de Frana           51.333333    52.5
#                 Belm                     52.000000    39.5
#                 Areeiro                  69.000000    69.0
# ...                                            ...     ...
# Private room    Estrela                  41.670270    40.0
#                 Benfica                  41.900000    42.0
#                 Avenidas Novas           44.284047    40.0
#                 Arroios                  44.522694    32.0
#                 Santo Antnio             44.865672    38.0
#                 Misericrdia              47.567251    39.0
#                 Belm                     50.087719    40.0
#                 Santa Maria Maior        50.431579    40.0
#                 Parque das Naes          56.324324    45.0
#                 Lumiar                   76.355556    31.0
# Shared room     Campolide                 9.750000    10.0
#                 Campo de Ourique         14.727273    13.0
#                 Belm                     15.000000    15.0
#                 Avenidas Novas           15.066667    13.0
#                 So Vicente               15.500000    13.5
#                 Areeiro                  16.041667    15.0
#                 Alcntara                 17.750000    18.0
#                 Marvila                  18.000000    18.0
#                 Misericrdia              18.454545    17.0
#                 Alvalade                 19.000000    16.0
#                 Benfica                  19.666667    20.0
#                 Arroios                  19.965517    15.0
#                 Santo Antnio             20.461538    20.0
#                 Penha de Frana           20.600000    14.0
#                 Santa Maria Maior        20.933333    15.0
#                 Ajuda                    25.000000    25.0
#                 Carnide                  25.000000    25.0
#                 Parque das Naes          25.000000    20.0
#                 Estrela                  29.000000    29.0
#                 Olivais                  45.000000    45.0
#
# [83 rows x 2 columns]

# %%
### FLEXIBILITY ###
data.columns
flexibility = data.groupby(['cancellation_policy','neighbourhood'])['price'].agg(['mean', 'median'])
flexibility
flexibility.sort_values(by=['cancellation_policy','mean'], ascending= True)
# Out:
#                                                           mean  median
# cancellation_policy         neighbourhood
# flexible                    Santa Clara              34.888889    20.0
#                             Olivais                  42.243902    40.0
#                             Benfica                  46.000000    44.0
#                             Lumiar                   48.733333    40.0
#                             Carnide                  51.666667    60.0
#                             Penha de Frana           54.511111    45.0
#                             Beato                    56.411765    52.0
#                             Marvila                  57.071429    40.0
#                             Alvalade                 57.382979    49.0
#                             So Domingos de Benfica   59.708333    45.0
#                             Campolide                60.368421    58.5
#                             Campo de Ourique         60.629630    59.5
#                             Areeiro                  61.555556    45.0
#                             Alcntara                 63.340909    53.0
#                             Avenidas Novas           64.137097    50.0
#                             Belm                     67.262295    60.0
#                             So Vicente               69.367816    62.0
#                             Arroios                  71.408638    56.0
#                             Estrela                  76.104294    60.0
#                             Santo Antnio             79.438710    70.0
#                             Misericrdia              88.690323    70.0
#                             Parque das Naes          90.524590    80.0
#                             Santa Maria Maior        92.842105    61.0
#                             Ajuda                    98.225806    55.0
# moderate                    Santa Clara              29.750000    25.5
#                             Beato                    46.783784    50.0
#                             Marvila                  48.333333    45.0
#                             Olivais                  55.472222    51.0
#                             Alvalade                 55.474359    50.0
#                             Penha de Frana           55.702247    50.0
# ...                                                        ...     ...
# strict_14_with_grace_period Misericrdia              87.677419    71.0
#                             Santo Antnio             88.124214    70.0
#                             Santa Maria Maior        88.685440    75.0
#                             Avenidas Novas           93.996139    59.0
#                             Parque das Naes         109.968750    94.5
#                             Marvila                 131.103448    65.0
#                             Santa Clara             149.400000    20.0
# super_strict_30             Avenidas Novas           88.333333    40.0
#                             So Domingos de Benfica   99.000000    99.0
#                             Campolide               102.500000   102.5
#                             Santo Antnio            105.000000   105.0
#                             Santa Maria Maior       133.800000   140.0
#                             Misericrdia             145.588235   130.0
#                             Arroios                 146.666667   165.0
#                             Estrela                 155.000000   155.0
#                             So Vicente              158.666667   160.0
#                             Benfica                 165.000000   165.0
#                             Parque das Naes         171.000000   171.0
# super_strict_60             Olivais                  29.000000    29.0
#                             Benfica                  60.000000    60.0
#                             Arroios                  62.000000    59.0
#                             Belm                     66.250000    57.0
#                             Misericrdia              69.600000    64.0
#                             Alcntara                 69.750000    30.0
#                             Avenidas Novas           77.000000    77.0
#                             Santa Maria Maior        88.869565    85.0
#                             Estrela                  90.400000    69.0
#                             Penha de Frana           97.000000    97.0
#                             So Vicente              102.250000    67.0
#                             Santo Antnio            163.666667   112.5
#
# [96 rows x 2 columns]

# %%
############### Wich is the best neighbouhood for each persona ########################
# Business: high flex, intermediate comfort, intermediate price
#Backpecker: high flex, low comfy, low price
#Family:low flex, high comfy,inter to high price, high score rating

# Filtrar aps para personas
# 'instant_bookable' == False
# 'cancellation_policy' != flexible
# 'require_guest_profile_picture' = True
# 'require_guest_phone_verification' = True


# condition = data(['instant_bookable'] == False)
# condition2 = data(['cancellation_policy'] != 'flexible')

# %%
# dropar rows contrarios, aos flexiveis aplicar filtro do preço ?

# %%
# Categorize neighbourhoods by price
# Create 5 bins and use the five labels above natural breaks

bins_labels = ['Very Low', 'Low', 'Moderate', 'High', 'Very High']
neighbourhoods_bins = pd.cut(data['price'],5, labels=bins_labels)
# Number of obs in each category
neighbourhoods_bins.value_counts()
# Out:
# Very Low     15726
# Very High        1
# Low              1
# High             0
# Moderate         0
# Name: price, dtype: int64

# %%
# Based in quartiles
bins_labels = ['Very Low', 'Low', 'Moderate', 'High', 'Very High']
neighbourhoods_bins = pd.qcut(data['price'],5, labels=bins_labels)
# Number of obs in each category
neighbourhoods_bins.value_counts()
# Out:
# Moderate     3375
# Very Low     3177
# Low          3150
# High         3116
# Very High    2910
# Name: price, dtype: int64

# %%
data['Categories'] = pd.qcut(data['price'],5, labels=bins_labels)
data.head()
# Out:
#       id                                       name    city  \
# 0   6499       Belém 1 Bedroom Historical Apartment  Lisboa
# 1  25659  Sunny,  Alfama  Sleeps 3 - Coeur d'Alfama  Lisboa
# 4  29248   Apartamento Alfama com vista para o rio!  Lisboa
# 5  29396           Alfama Hill - Boutique apartment  Lisboa
# 6  29720                TheHOUSE - Your luxury home  Lisboa
#
#        neighbourhood   price  value_money  \
# 0               Belm    40.0     2.275000
# 1  Santa Maria Maior    60.0     1.600000
# 4  Santa Maria Maior    60.0     1.516667
# 5  Santa Maria Maior    60.0     1.600000
# 6            Estrela  1000.0     0.098000
#
#                                          description  \
# 0  This apartment is all about Location, next to ...
# 1  Sunny 1 Bedroom cozy apartment in historic Alf...
# 4  Located in the city center, and great location...
# 5  Feel at home in the historic centre of Lisbon....
# 6  A house at the top of an anonimous building, T...
#
#                                neighborhood_overview property_type  \
# 0  To get  to the city center, tram 15 stops in f...     Apartment
# 1  Alfama is the oldest and most picturesque quar...     Apartment
# 4                                                NaN     Apartment
# 5  Great neighborhood in the old part of town. Am...     Apartment
# 6  Location in the city's Embassies area, near en...     Apartment
#
#          room_type  ...  listing_duration  review_scores_rating  \
# 0  Entire home/apt  ...              1949                  91.0
# 1  Entire home/apt  ...              2054                  96.0
# 4  Entire home/apt  ...              3223                  91.0
# 5  Entire home/apt  ...              2791                  96.0
# 6  Entire home/apt  ...              3285                  98.0
#
#    host_is_superhost  instant_bookable          cancellation_policy  \
# 0                  f                 t                     moderate
# 1                  t                 t                     moderate
# 4                  f                 t                     moderate
# 5                  f                 t  strict_14_with_grace_period
# 6                  t                 f  strict_14_with_grace_period
#
#   require_guest_profile_picture  require_guest_phone_verification  \
# 0                             f                                 f
# 1                             f                                 f
# 4                             f                                 f
# 5                             f                                 t
# 6                             f                                 t
#
#    calculated_host_listings_count  reviews_per_month Categories
# 0                               1               0.39   Very Low
# 1                               1               1.61   Moderate
# 4                               1               2.89   Moderate
# 5                               2               2.48   Moderate
# 6                               2               0.47  Very High
#
# [5 rows x 31 columns]
