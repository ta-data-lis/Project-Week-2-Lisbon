# %%
import pandas as pd

# %%
agenda = pd.read_json("agenda_cultural.json")

# %%
agenda.columns
# Out:
# Index(['ID', 'post_author', 'post_date', 'post_date_gmt', 'post_content',
#        'post_title', 'post_excerpt', 'post_status', 'comment_status',
#        'ping_status', 'post_password', 'post_name', 'to_ping', 'pinged',
#        'post_modified', 'post_modified_gmt', 'post_content_filtered',
#        'post_parent', 'guid', 'menu_order', 'post_type', 'post_mime_type',
#        'comment_count', 'filter', 'id', 'type', 'title', 'featured_media',
#        'featured_media_thumbnail', 'featured_media_medium',
#        'featured_media_large', 'subtitle', 'subject', 'string_dates',
#        'string_times', 'description', 'venue', 'categories_name_list',
#        'tags_name_list', 'link', 'occurences', 'StartDate', 'LastDate',
#        'price_cat', 'price_val', 'target_audience', 'accessibility'],
#       dtype='object')

# %%
agenda_lx = agenda[["ID","categories_name_list", "title", "venue", "occurences", "LastDate", "price_cat" ]]
agenda_lx.head()
# Out:
#       ID                               categories_name_list  \
# 0  24138  {'cinema': {'id': 38, 'slug': 'cinema', 'name'...
# 1  24137  {'musica': {'id': 42, 'slug': 'musica', 'name'...
# 2  24132  {'ciencia': {'id': 39, 'slug': 'ciencia', 'nam...
# 3  24109  {'cinema': {'id': 38, 'slug': 'cinema', 'name'...
# 4  24128  {'danca': {'id': 26, 'slug': 'danca', 'name': ...
#
#                                         title  \
# 0  {'rendered': '"O Farol" de Robert Eggers'}
# 1                 {'rendered': 'Resistência'}
# 2        {'rendered': 'Dinossauros Explorer'}
# 3            {'rendered': 'Especial Óscares'}
# 4           {'rendered': 'The Wake of Sleep'}
#
#                                                venue  \
# 0  {'espaco-nimas': {'id': 405, 'slug': 'espaco-n...
# 1  {'culturgest': {'id': 303, 'slug': 'culturgest...
# 2                                                 []
# 3  {'espaco-nimas': {'id': 405, 'slug': 'espaco-n...
# ...

# %%
agenda_lx["LastDate"].isnull().sum()
# Out:
# 0

# %%
agenda_lx["LastDate"] = pd.to_datetime(agenda_lx["LastDate"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
agenda_lx["Month"] = agenda_lx["LastDate"].dt.month
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
agenda_lx.head()
# Out:
#       ID                               categories_name_list  \
# 0  24138  {'cinema': {'id': 38, 'slug': 'cinema', 'name'...
# 1  24137  {'musica': {'id': 42, 'slug': 'musica', 'name'...
# 2  24132  {'ciencia': {'id': 39, 'slug': 'ciencia', 'nam...
# 3  24109  {'cinema': {'id': 38, 'slug': 'cinema', 'name'...
# 4  24128  {'danca': {'id': 26, 'slug': 'danca', 'name': ...
#
#                                         title  \
# 0  {'rendered': '"O Farol" de Robert Eggers'}
# 1                 {'rendered': 'Resistência'}
# 2        {'rendered': 'Dinossauros Explorer'}
# 3            {'rendered': 'Especial Óscares'}
# 4           {'rendered': 'The Wake of Sleep'}
#
#                                                venue  \
# 0  {'espaco-nimas': {'id': 405, 'slug': 'espaco-n...
# 1  {'culturgest': {'id': 303, 'slug': 'culturgest...
# 2                                                 []
# 3  {'espaco-nimas': {'id': 405, 'slug': 'espaco-n...
# ...

# %%
agenda_lx["Quarter"] = agenda_lx["LastDate"].dt.quarter
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
agenda_lx.head()
# Out:
#       ID                               categories_name_list  \
# 0  24138  {'cinema': {'id': 38, 'slug': 'cinema', 'name'...
# 1  24137  {'musica': {'id': 42, 'slug': 'musica', 'name'...
# 2  24132  {'ciencia': {'id': 39, 'slug': 'ciencia', 'nam...
# 3  24109  {'cinema': {'id': 38, 'slug': 'cinema', 'name'...
# 4  24128  {'danca': {'id': 26, 'slug': 'danca', 'name': ...
#
#                                         title  \
# 0  {'rendered': '"O Farol" de Robert Eggers'}
# 1                 {'rendered': 'Resistência'}
# 2        {'rendered': 'Dinossauros Explorer'}
# 3            {'rendered': 'Especial Óscares'}
# 4           {'rendered': 'The Wake of Sleep'}
#
#                                                venue  \
# 0  {'espaco-nimas': {'id': 405, 'slug': 'espaco-n...
# 1  {'culturgest': {'id': 303, 'slug': 'culturgest...
# 2                                                 []
# 3  {'espaco-nimas': {'id': 405, 'slug': 'espaco-n...
# ...

# %% [markdown]
# ### What is the month and quarter with the higher number of events?

# %%
# the months with more cultural offer are september, November and December.
# August is the month with the lowest cultural offer
agenda_lx.groupby("Month").count()
# Out:
#         ID  categories_name_list  title  venue  occurences  LastDate  \
# Month
# 1      481                   481    481    481         481       481
# 2      496                   496    496    496         496       496
# 3      418                   418    418    418         418       418
# 4      335                   335    335    335         335       335
# 5      406                   406    406    406         406       406
# 6      482                   482    482    482         482       482
# 7      426                   426    426    426         426       426
# 8      170                   170    170    170         170       170
# 9      673                   673    673    673         673       673
# 10     594                   594    594    594         594       594
# 11     703                   703    703    703         703       703
# 12     676                   676    676    676         676       676
#
#        price_cat  Quarter
# Month
# 1            481      481
# ...

# %%
agenda_lx.groupby("Quarter").count()

# quarter 4 has a lot more offer
# Out:
#            ID  categories_name_list  title  venue  occurences  LastDate  \
# Quarter
# 1        1395                  1395   1395   1395        1395      1395
# 2        1223                  1223   1223   1223        1223      1223
# 3        1269                  1269   1269   1269        1269      1269
# 4        1973                  1973   1973   1973        1973      1973
#
#          price_cat  Month
# Quarter
# 1             1395   1395
# 2             1223   1223
# 3             1269   1269
# 4             1973   1973
