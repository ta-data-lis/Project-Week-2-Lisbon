# %%
# Importing the pandas library as pd

import pandas as pd

# %%
# Reading the CSV files 

unemployment = pd.read_csv('unemployment.csv')

# Checking how many rows & columns we have

unemployment.shape
# Out:
# (14208, 9)

# %%
# Inspecting the data

unemployment.head()
# Out:
#    Year    Month  District Code District Name  Neighborhood Code  \
# 0  2017  January              1  Ciutat Vella                  1
# 1  2017  January              1  Ciutat Vella                  2
# 2  2017  January              1  Ciutat Vella                  3
# 3  2017  January              1  Ciutat Vella                  4
# 4  2017  January              2      Eixample                  5
#
#                        Neighborhood Name Gender      Demand_occupation  Number
# 0                               el Raval   Male  Registered unemployed    2107
# 1                         el Barri Gòtic   Male  Registered unemployed     538
# 2                         la Barceloneta   Male  Registered unemployed     537
# 3  Sant Pere, Santa Caterina i la Ribera   Male  Registered unemployed     741
# 4                          el Fort Pienc   Male  Registered unemployed     630

# %%
# We use the data of the month January in the unemployment dataset as our reference values and drop the other months.
# We also only use the already as unemployed registered people.

clean_unemployment = unemployment[(unemployment['Month'] == "January") &
                                           (unemployment['Demand_occupation'] == "Registered unemployed")]

# %%
# View the new dataset clean_unemployment

clean_unemployment.head()
print(clean_unemployment.shape)
# Out:
# (740, 9)

# %%
clean_unemployment.sort_values(by=['Number'])
# Out:
#        Year    Month  District Code District Name  Neighborhood Code  \
# 10803  2014  January             99     No consta                 99
# 10729  2014  January             99     No consta                 99
# 7325   2015  January             99     No consta                 99
# 12579  2013  January             99     No consta                 99
# 3773   2016  January             99     No consta                 99
# ...     ...      ...            ...           ...                ...
# 12565  2013  January              9   Sant Andreu                 60
# 3552   2016  January              1  Ciutat Vella                  1
# 7104   2015  January              1  Ciutat Vella                  1
# 10656  2014  January              1  Ciutat Vella                  1
# 12432  2013  January              1  Ciutat Vella                  1
#
#       Neighborhood Name  Gender      Demand_occupation  Number
# 10803         No consta  Female  Registered unemployed       0
# 10729         No consta    Male  Registered unemployed       0
# 7325          No consta  Female  Registered unemployed       1
# 12579         No consta  Female  Registered unemployed       2
# 3773          No consta  Female  Registered unemployed       2
# ...                 ...     ...                    ...     ...
# 12565       Sant Andreu  Female  Registered unemployed    2200
# 3552           el Raval    Male  Registered unemployed    2431
# 7104           el Raval    Male  Registered unemployed    2688
# 10656          el Raval    Male  Registered unemployed    2864
# 12432          el Raval    Male  Registered unemployed    3012
#
# [740 rows x 9 columns]

# %%
# Check with .describe() method

clean_unemployment.describe()
# Out:
#              Year  District Code  Neighborhood Code       Number
# count   740.00000     740.000000         740.000000   740.000000
# mean   2015.00000       7.500000          37.837838   666.710811
# std       1.41517      11.069042          22.133820   465.974789
# min    2013.00000       1.000000           1.000000     0.000000
# 25%    2014.00000       4.000000          19.000000   315.500000
# 50%    2015.00000       7.000000          37.500000   587.000000
# 75%    2016.00000       8.000000          56.000000   956.250000
# max    2017.00000      99.000000          99.000000  3012.000000

# %%
# Check for missing values 
## NaN

clean_unemployment.isnull().sum()
# Out:
# Year                 0
# Month                0
# District Code        0
# District Name        0
# Neighborhood Code    0
# Neighborhood Name    0
# Gender               0
# Demand_occupation    0
# Number               0
# dtype: int64

# %%
# Check for other values that do not belong to the dataframe

clean_unemployment.tail()
# Out:
#        Year    Month  District Code District Name  Neighborhood Code  \
# 12575  2013  January             10    Sant Martí                 70
# 12576  2013  January             10    Sant Martí                 71
# 12577  2013  January             10    Sant Martí                 72
# 12578  2013  January             10    Sant Martí                 73
# 12579  2013  January             99     No consta                 99
#
#               Neighborhood Name  Gender      Demand_occupation  Number
# 12575     el Besòs i el Maresme  Female  Registered unemployed    1084
# 12576   Provençals del Poblenou  Female  Registered unemployed     771
# 12577  Sant Martí de Provençals  Female  Registered unemployed    1061
# 12578       la Verneda i la Pau  Female  Registered unemployed    1197
# 12579                 No consta  Female  Registered unemployed       2

# %%
# to delete 99 neighborhood code

clean_unemployment = clean_unemployment[clean_unemployment["Neighborhood Code"] != 99]

print("Deleted 1 row with 99 value.")
clean_unemployment.tail()
# Out:
# Deleted 1 row with 99 value.
#        Year    Month  District Code District Name  Neighborhood Code  \
# 12574  2013  January             10    Sant Martí                 69
# 12575  2013  January             10    Sant Martí                 70
# 12576  2013  January             10    Sant Martí                 71
# 12577  2013  January             10    Sant Martí                 72
# 12578  2013  January             10    Sant Martí                 73
#
#                                   Neighborhood Name  Gender  \
# 12574  Diagonal Mar i el Front Marítim del Poblenou  Female
# 12575                         el Besòs i el Maresme  Female
# 12576                       Provençals del Poblenou  Female
# 12577                      Sant Martí de Provençals  Female
# 12578                           la Verneda i la Pau  Female
#
#            Demand_occupation  Number
# 12574  Registered unemployed     474
# 12575  Registered unemployed    1084
# 12576  Registered unemployed     771
# 12577  Registered unemployed    1061
# 12578  Registered unemployed    1197

# %%
## NEXT DATASET immigrants by nationality

# %%
# import dataset immigrants by nationality

immigrants_nat = pd.read_csv('immigrants_by_nationality.csv')
immigrants_nat.head()
# Out:
#    Year  District Code District Name  Neighborhood Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood Name Nationality  Number
# 0                               el Raval       Spain    1109
# 1                         el Barri Gòtic       Spain     482
# 2                         la Barceloneta       Spain     414
# 3  Sant Pere, Santa Caterina i la Ribera       Spain     537
# 4                          el Fort Pienc       Spain     663

# %%
# Get rid of District code and District Name
clean_immigrants = immigrants_nat[["Year", "Neighborhood Code", "Neighborhood Name", "Nationality", "Number"]]
clean_immigrants = clean_immigrants.sort_values("Year")
clean_immigrants.head()
# Out:
#        Year  Neighborhood Code          Neighborhood Name     Nationality  \
# 35223  2015                 99                  No consta  No information
# 27630  2015                 29                    el Coll           Syria
# 27629  2015                 28  Vallcarca i els Penitents           Syria
# 27628  2015                 27       el Putxet i el Farró           Syria
# 27627  2015                 26     Sant Gervasi - Galvany           Syria
#
#        Number
# 35223       0
# 27630       0
# 27629       1
# 27628       3
# 27627       4

# %%
clean_immigrants.shape
# Out:
# (35224, 5)

# %%
# Look at the datasets using the .describe() method

clean_immigrants.describe()
# Out:
#                Year  Neighborhood Code        Number
# count  35224.000000       35224.000000  35224.000000
# mean    2016.010504          37.837838      7.707273
# std        0.810846          22.119174     50.421883
# min     2015.000000           1.000000      0.000000
# 25%     2015.000000          19.000000      0.000000
# 50%     2016.000000          37.500000      0.000000
# 75%     2017.000000          56.000000      2.000000
# max     2017.000000          99.000000   1603.000000

# %%
# Get rid of Nationality without information
clean_immigrants = clean_immigrants[clean_immigrants.Nationality != "No information"]
clean_immigrants.head()
# Out:
#        Year  Neighborhood Code           Neighborhood Name Nationality  Number
# 27630  2015                 29                     el Coll       Syria       0
# 27629  2015                 28   Vallcarca i els Penitents       Syria       1
# 27628  2015                 27        el Putxet i el Farró       Syria       3
# 27627  2015                 26      Sant Gervasi - Galvany       Syria       4
# 27626  2015                 25  Sant Gervasi - la Bonanova       Syria       1

# %%
# Dropped 222 rows where no info on Nationality
clean_immigrants.shape
# Out:
# (35002, 5)

# %%
# Get rid of Neighborhood Code that dont have meaning
clean_immigrants = clean_immigrants[clean_immigrants["Neighborhood Code"] != 99]
clean_immigrants.head()
# Out:
#        Year  Neighborhood Code           Neighborhood Name Nationality  Number
# 27630  2015                 29                     el Coll       Syria       0
# 27629  2015                 28   Vallcarca i els Penitents       Syria       1
# 27628  2015                 27        el Putxet i el Farró       Syria       3
# 27627  2015                 26      Sant Gervasi - Galvany       Syria       4
# 27626  2015                 25  Sant Gervasi - la Bonanova       Syria       1

# %%
# Dropped 473 rows with 99 values
clean_immigrants.shape
# Out:
# (34529, 5)

# %%
# Number of unique nationalities in the city
n = clean_immigrants["Nationality"].unique()
len(n)
# Out:
# 176

# %%
# Immigrants grouped by Neighborhoods and number of immigrants in every neighborhood
# for the year 2017

immigrants_2017 = clean_immigrants[clean_immigrants['Year']== 2017]
                                         
immigrants_2017_byhood = immigrants_2017.groupby(['Neighborhood Code',"Neighborhood Name"], 
                                                 as_index=False).agg({'Number': "sum"})
immigrants_2017_byhood.head()
# Out:
#    Neighborhood Code                      Neighborhood Name  Number
# 0                  1                               el Raval    5398
# 1                  2                         el Barri Gòtic    2686
# 2                  3                         la Barceloneta    1759
# 3                  4  Sant Pere, Santa Caterina i la Ribera    2765
# 4                  5                          el Fort Pienc    2235

# %%
# Immigrants grouped by Neighborhoods and the number of immigrants in every neighborhood
# for the year 2016
immigrants_2016 = clean_immigrants[clean_immigrants['Year']== 2016]
                                         
immigrants_2016_byhood = immigrants_2016.groupby(['Neighborhood Code',"Neighborhood Name"], 
                                                 as_index=False).agg({'Number': "sum"})
immigrants_2016_byhood.head()
# Out:
#    Neighborhood Code                      Neighborhood Name  Number
# 0                  1                               el Raval    4975
# 1                  2                         el Barri Gòtic    2197
# 2                  3                         la Barceloneta    1547
# 3                  4  Sant Pere, Santa Caterina i la Ribera    2376
# 4                  5                          el Fort Pienc    1990

# %%
# Immigrants that groped by Neighborhoods and the number of imigrants in every neighborhood
# for the year 2015
immigrants_2015 = clean_immigrants[clean_immigrants['Year']== 2015]
                                         
immigrants_2015_byhood = immigrants_2015.groupby(['Neighborhood Code',"Neighborhood Name"], 
                                                 as_index=False).agg({'Number': "sum"})
immigrants_2015_byhood.head()
# Out:
#    Neighborhood Code                      Neighborhood Name  Number
# 0                  1                               el Raval    5335
# 1                  2                         el Barri Gòtic    2201
# 2                  3                         la Barceloneta    1553
# 3                  4  Sant Pere, Santa Caterina i la Ribera    2551
# 4                  5                          el Fort Pienc    2000

# %%
# Total immigrants by years
immigrants_2015_total = immigrants_2015_byhood["Number"].sum()
immigrants_2016_total = immigrants_2016_byhood["Number"].sum()
immigrants_2017_total = immigrants_2017_byhood["Number"].sum()

print("Total imigrants in 2017 = ", immigrants_2017_total)
print("Total imigrants in 2016 = ", immigrants_2016_total)
print("Total imigrants in 2015 = ", immigrants_2015_total)
# Out:
# Total imigrants in 2017 =  97280
# Total imigrants in 2016 =  85123
# Total imigrants in 2015 =  88911

# %%
# Check if data types make sense

print(clean_immigrants.dtypes)
# Out:
# Year                  int64
# Neighborhood Code     int64
# Neighborhood Name    object
# Nationality          object
# Number                int64
# dtype: object

# %%
print(clean_unemployment.dtypes)
# Out:
# Year                  int64
# Month                object
# District Code         int64
# District Name        object
# Neighborhood Code     int64
# Neighborhood Name    object
# Gender               object
# Demand_occupation    object
# Number                int64
# dtype: object

# %%
# Importing the population datasets for the years 2015,2016 & 2017
population_2017 = pd.read_csv ("pop2017.csv")
population_2016 = pd.read_csv ("pop2016.csv")
population_2015 = pd.read_csv ("pop2015.csv")

# %%
# Adding all 3 years of population datasets together to 1 dataset: population_original

population_original = pd.concat([population_2017, population_2016, population_2015])
population_original.columns=['Year', "District Code", "District Name" ,"Neighborhood Code" ,"Neighborhood Name", 
                             "Gender", "Number"]
population_original.head()
# Out:
#    Year  District Code District Name  Neighborhood Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood Name Gender  Number
# 0                               el Raval  Homes   26022
# 1                         el Barri Gòtic  Homes    8440
# 2                         la Barceloneta  Homes    7511
# 3  Sant Pere, Santa Caterina i la Ribera  Homes   11431
# 4                          el Fort Pienc  Homes   15086

# %%
# Use .describe to inspect the population dataset

population_original.describe()
# Out:
#               Year  District Code  Neighborhood Code        Number
# count   440.000000     440.000000         440.000000    440.000000
# mean   2015.995455       6.668182          37.281818  11011.622727
# std       0.818342       6.839113          21.457435   7326.968628
# min    2015.000000       1.000000           1.000000      0.000000
# 25%    2015.000000       4.000000          19.000000   5195.000000
# 50%    2016.000000       7.000000          37.000000   9938.000000
# 75%    2017.000000       8.000000          55.250000  15315.250000
# max    2017.000000      99.000000          99.000000  31257.000000

# %%
# Cleaning the population_original dataset and storing it into: clean_pop

clean_pop = population_original[(population_original['Neighborhood Code'] != 99)]
print(clean_pop.shape)
clean_pop.head()
# Out:
# (438, 7)
#    Year  District Code District Name  Neighborhood Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood Name Gender  Number
# 0                               el Raval  Homes   26022
# 1                         el Barri Gòtic  Homes    8440
# 2                         la Barceloneta  Homes    7511
# 3  Sant Pere, Santa Caterina i la Ribera  Homes   11431
# 4                          el Fort Pienc  Homes   15086

# %%
# We now want to filter by year

year = 2017

unemployment_year = clean_unemployment[clean_unemployment['Year']== year]

immigrants_year = clean_immigrants[clean_immigrants['Year']== year]       

population_year = clean_pop[clean_pop['Year']== year]

unemployment_year.shape
# Out:
# (146, 9)

# %%
# Grouping the datasets by Neighborhood

immigrants_agg = immigrants_year.groupby(['Neighborhood Code',"Neighborhood Name"], as_index=False).agg({'Number': "sum"})

unemployment_agg = unemployment_year.groupby(['Neighborhood Code',"Neighborhood Name"], as_index=False).agg({'Number': "sum"})

population_agg = population_year.groupby(['Neighborhood Code',"Neighborhood Name"], as_index=False).agg({'Number': "sum"})

# %%
# Grouping the unemployment dataset by gender

unemployment_gender_agg = unemployment_year.groupby(['Neighborhood Code',"Neighborhood Name", "Gender"], as_index=False).agg({'Number': "sum"})

# Renaming columns

immigrants_agg = immigrants_agg.rename(columns = {"Number": "Total Immigrants"})

unemployment_agg = unemployment_agg.rename(columns = {"Number": "Registered Unemployed"})

population_agg = population_agg.rename(columns = {"Number": "Total Residents"})

# %%
unemployment_agg.sort_values(by='Registered Unemployed', ascending=False).head()
# Out:
#     Neighborhood Code               Neighborhood Name  Registered Unemployed
# 0                   1                        el Raval                   3976
# 59                 60                     Sant Andreu                   3497
# 10                 11                    el Poble Sec                   2802
# 8                   9  la Nova Esquerra de l'Eixample                   2684
# 5                   6              la Sagrada Família                   2480

# %%
unemployment_gender_agg = unemployment_gender_agg.rename(columns = {"Number": "Registered Unemployed"})
unemployment_gender_agg.sort_values(by=['Registered Unemployed','Neighborhood Code','Gender'],ascending = False).head()
# Out:
#      Neighborhood Code Neighborhood Name  Gender  Registered Unemployed
# 1                    1          el Raval    Male                   2688
# 118                 60       Sant Andreu  Female                   2092
# 119                 60       Sant Andreu    Male                   1792
# 21                  11      el Poble Sec    Male                   1700
# 0                    1          el Raval  Female                   1680

# %%
immigrants_agg.sort_values(by=['Total Immigrants'],ascending = False).head()
# Out:
#     Neighborhood Code                Neighborhood Name  Total Immigrants
# 0                   1                         el Raval              5398
# 8                   9   la Nova Esquerra de l'Eixample              4058
# 5                   6               la Sagrada Família              3589
# 30                 31                la Vila de Gràcia              3584
# 7                   8  l'Antiga Esquerra de l'Eixample              3464

# %%
population_agg.head()
# Out:
#    Neighborhood Code                      Neighborhood Name  Total Residents
# 0                  1                               el Raval            47274
# 1                  2                         el Barri Gòtic            15729
# 2                  3                         la Barceloneta            15068
# 3                  4  Sant Pere, Santa Caterina i la Ribera            22380
# 4                  5                          el Fort Pienc            31693

# %%
# Merging tables aggregated unemployment and aggregated immigrants on Neighborhood

merged_unemp_immigr = unemployment_agg.merge(immigrants_agg, on= ['Neighborhood Code',"Neighborhood Name"])

Barcelona_Neighborhoods = merged_unemp_immigr.merge(population_agg, on= ['Neighborhood Code',"Neighborhood Name"])

# %%
# Adding column ratio, that shows the % of immigrants over residents per Neighborhood

Barcelona_Neighborhoods["Ratio_Immigrants"] = Barcelona_Neighborhoods['Total Immigrants'] / Barcelona_Neighborhoods["Total Residents"]

Barcelona_Neighborhoods["Ratio_Unemployed"] = Barcelona_Neighborhoods['Registered Unemployed'] / Barcelona_Neighborhoods["Total Residents"]

Barcelona_Neighborhoods["Ratio_Immigrants_Unemployed"] = Barcelona_Neighborhoods['Total Immigrants'] / Barcelona_Neighborhoods["Registered Unemployed"]


Barcelona_Neighborhoods.head()
# Out:
#    Neighborhood Code                      Neighborhood Name  \
# 0                  1                               el Raval
# 1                  2                         el Barri Gòtic
# 2                  3                         la Barceloneta
# 3                  4  Sant Pere, Santa Caterina i la Ribera
# 4                  5                          el Fort Pienc
#
#    Registered Unemployed  Total Immigrants  Total Residents  Ratio_Immigrants  \
# 0                   3976              4975            47274          0.105238
# 1                   1051              2197            15729          0.139678
# 2                   1223              1547            15068          0.102668
# 3                   1691              2376            22380          0.106166
# 4                   1479              1990            31693          0.062790
#
#    Ratio_Unemployed  Ratio_Immigrants_Unemployed
# 0          0.084105                     1.251258
# 1          0.066819                     2.090390
# 2          0.081165                     1.264922
# 3          0.075559                     1.405086
# 4          0.046666                     1.345504

# %%
Barcelona_Neighborhoods.sort_values(by=['Ratio_Immigrants'], ascending=False)
# Out:
#     Neighborhood Code                      Neighborhood Name  \
# 1                   2                         el Barri Gòtic
# 3                   4  Sant Pere, Santa Caterina i la Ribera
# 0                   1                               el Raval
# 2                   3                         la Barceloneta
# 69                 70                  el Besòs i el Maresme
# ..                ...                                    ...
# 47                 48                           la Guineueta
# 46                 47                            Can Peguera
# 11                 12             la Marina del Prat Vermell
# 35                 36                   la Font d'en Fargues
# 48                 49                              Canyelles
#
#     Registered Unemployed  Total Immigrants  Total Residents  \
# 1                    1051              2197            15729
# 3                    1691              2376            22380
# 0                    3976              4975            47274
# 2                    1223              1547            15068
# 69                   1833              1575            22609
# ..                    ...               ...              ...
# 47                   1122               464            15050
# 46                    141                68             2216
# 11                    151                35             1146
# 35                    607               202             9402
# 48                    547               129             6925
#
#     Ratio_Immigrants  Ratio_Unemployed  Ratio_Immigrants_Unemployed
# 1           0.139678          0.066819                     2.090390
# 3           0.106166          0.075559                     1.405086
# 0           0.105238          0.084105                     1.251258
# 2           0.102668          0.081165                     1.264922
# 69          0.069663          0.081074                     0.859247
# ..               ...               ...                          ...
# 47          0.030831          0.074551                     0.413547
# 46          0.030686          0.063628                     0.482270
# 11          0.030541          0.131763                     0.231788
# 35          0.021485          0.064561                     0.332784
# 48          0.018628          0.078989                     0.235832
#
# [73 rows x 8 columns]
