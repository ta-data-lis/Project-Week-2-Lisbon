# %%
# Importing the pandas library as pd

import pandas as pd

# %%
# Reading the CSV files 

unemployment = pd.read_csv('unemployment.csv')

# Checking how many rows & columns we have

unemployment.shape
# Out:
# (14208, 9)

# %%
# Inspecting the data

unemployment.head()
# Out:
#    Year    Month  District Code District Name  Neighborhood Code  \
# 0  2017  January              1  Ciutat Vella                  1
# 1  2017  January              1  Ciutat Vella                  2
# 2  2017  January              1  Ciutat Vella                  3
# 3  2017  January              1  Ciutat Vella                  4
# 4  2017  January              2      Eixample                  5
#
#                        Neighborhood Name Gender      Demand_occupation  Number
# 0                               el Raval   Male  Registered unemployed    2107
# 1                         el Barri Gòtic   Male  Registered unemployed     538
# 2                         la Barceloneta   Male  Registered unemployed     537
# 3  Sant Pere, Santa Caterina i la Ribera   Male  Registered unemployed     741
# 4                          el Fort Pienc   Male  Registered unemployed     630

# %%
# We create a new dataframe: we will drop Month, District Code, District Name 

unemployment_filtered = unemployment[['Year','Neighborhood Code','Neighborhood Name','Gender','Demand_occupation','Number']]

# %%
# We drop years 2013 and 2014 since these are not in our other dataset that we use for comparison

unemployment_filtered = unemployment_filtered[unemployment_filtered['Year']>2014]

# %%
# The new dataframe is named unemployment_filtered

unemployment_filtered.head()
# Out:
#    Year  Neighborhood Code                      Neighborhood Name Gender  \
# 0  2017                  1                               el Raval   Male
# 1  2017                  2                         el Barri Gòtic   Male
# 2  2017                  3                         la Barceloneta   Male
# 3  2017                  4  Sant Pere, Santa Caterina i la Ribera   Male
# 4  2017                  5                          el Fort Pienc   Male
#
#        Demand_occupation  Number
# 0  Registered unemployed    2107
# 1  Registered unemployed     538
# 2  Registered unemployed     537
# 3  Registered unemployed     741
# 4  Registered unemployed     630

# %%
# Shape of the new dataframe unemployment_filtered

unemployment_filtered.shape
# Out:
# (10656, 6)

# %%
# Check with .describe() method

unemployment_filtered.describe()
# Out:
#                Year  Neighborhood Code        Number
# count  10656.000000       10656.000000  10656.000000
# mean    2016.000000          37.837838    354.160191
# std        0.816535          22.119898    356.028668
# min     2015.000000           1.000000      0.000000
# 25%     2015.000000          19.000000     97.000000
# 50%     2016.000000          37.500000    217.000000
# 75%     2017.000000          56.000000    511.000000
# max     2017.000000          99.000000   2688.000000

# %%
# Check for missing values 
## NaN

unemployment_filtered.isnull().sum()
# Out:
# Year                 0
# Neighborhood Code    0
# Neighborhood Name    0
# Gender               0
# Demand_occupation    0
# Number               0
# dtype: int64

# %%
# Check for other values that do not belong to the dataframe

unemployment_filtered.tail()
# Out:
#        Year  Neighborhood Code         Neighborhood Name  Gender  \
# 10651  2015                 70     el Besòs i el Maresme  Female
# 10652  2015                 71   Provençals del Poblenou  Female
# 10653  2015                 72  Sant Martí de Provençals  Female
# 10654  2015                 73       la Verneda i la Pau  Female
# 10655  2015                 99                 No consta  Female
#
#          Demand_occupation  Number
# 10651  Unemployment demand     173
# 10652  Unemployment demand     132
# 10653  Unemployment demand     197
# 10654  Unemployment demand     225
# 10655  Unemployment demand      27

# %%
# to delete 99 neighborhood code

unemployment_filtered = unemployment_filtered[unemployment_filtered["Neighborhood Code"] != 99]
unemployment_filtered.tail()
# Out:
#        Year  Neighborhood Code                             Neighborhood Name  \
# 10650  2015                 69  Diagonal Mar i el Front Marítim del Poblenou
# 10651  2015                 70                         el Besòs i el Maresme
# 10652  2015                 71                       Provençals del Poblenou
# 10653  2015                 72                      Sant Martí de Provençals
# 10654  2015                 73                           la Verneda i la Pau
#
#        Gender    Demand_occupation  Number
# 10650  Female  Unemployment demand      75
# 10651  Female  Unemployment demand     173
# 10652  Female  Unemployment demand     132
# 10653  Female  Unemployment demand     197
# 10654  Female  Unemployment demand     225

# %%
## NEXT DATASET immigrants by nationality

# %%
# import dataset immigrants by nationality

immigrants_nat = pd.read_csv('immigrants_by_nationality.csv')
immigrants_nat.head()
# Out:
#    Year  District Code District Name  Neighborhood Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood Name Nationality  Number
# 0                               el Raval       Spain    1109
# 1                         el Barri Gòtic       Spain     482
# 2                         la Barceloneta       Spain     414
# 3  Sant Pere, Santa Caterina i la Ribera       Spain     537
# 4                          el Fort Pienc       Spain     663

# %%
#Get rid of District code and District Name
immigrants_nat_clean = immigrants_nat[["Year", "Neighborhood Code", "Neighborhood Name", "Nationality", "Number"]]
immigrants_nat_clean = immigrants_nat_clean.sort_values("Year")
immigrants_nat_clean.head()
# Out:
#        Year  Neighborhood Code          Neighborhood Name     Nationality  \
# 35223  2015                 99                  No consta  No information
# 27630  2015                 29                    el Coll           Syria
# 27629  2015                 28  Vallcarca i els Penitents           Syria
# 27628  2015                 27       el Putxet i el Farró           Syria
# 27627  2015                 26     Sant Gervasi - Galvany           Syria
#
#        Number
# 35223       0
# 27630       0
# 27629       1
# 27628       3
# 27627       4

# %%
immigrants_nat.shape
# Out:
# (35224, 7)

# %%
# Look at the datasets using the .describe() method

immigrants_nat_clean.describe()
# Out:
#                Year  Neighborhood Code        Number
# count  35224.000000       35224.000000  35224.000000
# mean    2016.010504          37.837838      7.707273
# std        0.810846          22.119174     50.421883
# min     2015.000000           1.000000      0.000000
# 25%     2015.000000          19.000000      0.000000
# 50%     2016.000000          37.500000      0.000000
# 75%     2017.000000          56.000000      2.000000
# max     2017.000000          99.000000   1603.000000

# %%
#Get rid of Nationality without information
immigrants_nat_clean = immigrants_nat_clean[immigrants_nat_clean.Nationality != "No information"]
immigrants_nat_clean.head()
# Out:
#        Year  Neighborhood Code           Neighborhood Name Nationality  Number
# 27630  2015                 29                     el Coll       Syria       0
# 27629  2015                 28   Vallcarca i els Penitents       Syria       1
# 27628  2015                 27        el Putxet i el Farró       Syria       3
# 27627  2015                 26      Sant Gervasi - Galvany       Syria       4
# 27626  2015                 25  Sant Gervasi - la Bonanova       Syria       1

# %%
#Less 222 rows
immigrants_nat_clean.shape
# Out:
# (35002, 5)

# %%
#Get rid of Neighborhood Code that dont have meaning
immigrants_nat_clean = immigrants_nat_clean[immigrants_nat_clean["Neighborhood Code"] != 99]
immigrants_nat_clean.head()
# Out:
#        Year  Neighborhood Code           Neighborhood Name Nationality  Number
# 27630  2015                 29                     el Coll       Syria       0
# 27629  2015                 28   Vallcarca i els Penitents       Syria       1
# 27628  2015                 27        el Putxet i el Farró       Syria       3
# 27627  2015                 26      Sant Gervasi - Galvany       Syria       4
# 27626  2015                 25  Sant Gervasi - la Bonanova       Syria       1

# %%
#Less 473 rows
immigrants_nat_clean.shape
# Out:
# (34529, 5)

# %%
#Number of unique nationalities in the city
n = immigrants_nat_clean["Nationality"].unique()
len(n)
# Out:
# 176

# %%
#Immigrants that groped by Neighborhoods and the number of imigrants in every neighborhood
#for the year 2017
immigrants_2017 = immigrants_nat_clean[immigrants_nat_clean['Year']== 2017]
                                         
immigrants_2017_byhood = immigrants_2017.groupby(['Neighborhood Code',"Neighborhood Name"], 
                                                 as_index=False).agg({'Number': "sum"})
immigrants_2017_byhood.head()
# Out:
#    Neighborhood Code                      Neighborhood Name  Number
# 0                  1                               el Raval    5398
# 1                  2                         el Barri Gòtic    2686
# 2                  3                         la Barceloneta    1759
# 3                  4  Sant Pere, Santa Caterina i la Ribera    2765
# 4                  5                          el Fort Pienc    2235

# %%
#Immigrants that groped by Neighborhoods and the number of imigrants in every neighborhood
#for the year 2016
immigrants_2016 = immigrants_nat_clean[immigrants_nat_clean['Year']== 2016]
                                         
immigrants_2016_byhood = immigrants_2016.groupby(['Neighborhood Code',"Neighborhood Name"], 
                                                 as_index=False).agg({'Number': "sum"})
immigrants_2016_byhood.head()
# Out:
#    Neighborhood Code                      Neighborhood Name  Number
# 0                  1                               el Raval    4975
# 1                  2                         el Barri Gòtic    2197
# 2                  3                         la Barceloneta    1547
# 3                  4  Sant Pere, Santa Caterina i la Ribera    2376
# 4                  5                          el Fort Pienc    1990

# %%
#Immigrants that groped by Neighborhoods and the number of imigrants in every neighborhood
#for the year 2015
immigrants_2015 = immigrants_nat_clean[immigrants_nat_clean['Year']== 2015]
                                         
immigrants_2015_byhood = immigrants_2015.groupby(['Neighborhood Code',"Neighborhood Name"], 
                                                 as_index=False).agg({'Number': "sum"})
immigrants_2015_byhood.head()
# Out:
#    Neighborhood Code                      Neighborhood Name  Number
# 0                  1                               el Raval    5335
# 1                  2                         el Barri Gòtic    2201
# 2                  3                         la Barceloneta    1553
# 3                  4  Sant Pere, Santa Caterina i la Ribera    2551
# 4                  5                          el Fort Pienc    2000

# %%
#Total immigrants by years
immigrants_2015_total = immigrants_2015_byhood["Number"].sum()
immigrants_2016_total = immigrants_2016_byhood["Number"].sum()
immigrants_2017_total = immigrants_2017_byhood["Number"].sum()

print("Total imigrants in 2017 = ", immigrants_2017_total)
print("Total imigrants in 2016 = ", immigrants_2016_total)
print("Total imigrants in 2015 = ", immigrants_2015_total)
# Out:
# Total imigrants in 2017 =  97280
# Total imigrants in 2016 =  85123
# Total imigrants in 2015 =  88911

# %%
immigrants_nat_clean.tail()
print(immigrants_nat_clean.shape)
immigrants_nat_clean.head()
# Out:
# (34529, 5)
#        Year  Neighborhood Code           Neighborhood Name Nationality  Number
# 27630  2015                 29                     el Coll       Syria       0
# 27629  2015                 28   Vallcarca i els Penitents       Syria       1
# 27628  2015                 27        el Putxet i el Farró       Syria       3
# 27627  2015                 26      Sant Gervasi - Galvany       Syria       4
# 27626  2015                 25  Sant Gervasi - la Bonanova       Syria       1

# %%
# Check if data types make sense

print(immigrants_nat_clean.dtypes)
# Out:
# Year                  int64
# Neighborhood Code     int64
# Neighborhood Name    object
# Nationality          object
# Number                int64
# dtype: object

# %%
print(unemployment_filtered.dtypes)
# Out:
# Year                  int64
# Neighborhood Code     int64
# Neighborhood Name    object
# Gender               object
# Demand_occupation    object
# Number                int64
# dtype: object

# %%
#### HERE GROUP BY NEIGHBORHOOD CODE

# %%
### THIS IS A DRAFT

# Merge datasets

combined = immigrants_nat.merge(unemployment, on='Neighborhood Code', how='inner')

# %%
combined.shape
# Out:
# (6763008, 15)

# %%
combined.head()
# Out:
#    Year_x  District Code_x District Name_x  Neighborhood Code  \
# 0    2017                1    Ciutat Vella                  1
# 1    2017                1    Ciutat Vella                  1
# 2    2017                1    Ciutat Vella                  1
# 3    2017                1    Ciutat Vella                  1
# 4    2017                1    Ciutat Vella                  1
#
#   Neighborhood Name_x Nationality  Number_x  Year_y     Month  \
# 0            el Raval       Spain      1109    2017   January
# 1            el Raval       Spain      1109    2017   January
# 2            el Raval       Spain      1109    2017   January
# 3            el Raval       Spain      1109    2017   January
# 4            el Raval       Spain      1109    2017  February
#
#    District Code_y District Name_y Neighborhood Name_y  Gender  \
# 0                1    Ciutat Vella            el Raval    Male
# 1                1    Ciutat Vella            el Raval    Male
# 2                1    Ciutat Vella            el Raval  Female
# 3                1    Ciutat Vella            el Raval  Female
# 4                1    Ciutat Vella            el Raval    Male
#
#        Demand_occupation  Number_y
# 0  Registered unemployed      2107
# 1    Unemployment demand       429
# 2  Registered unemployed      1452
# 3    Unemployment demand       288
# 4  Registered unemployed      2063

# %%
# Drop columns that are not interesting for the analysis and save in a new dataframe

combined_new = combined.drop(['Month', 'District Code_x','District Name_x','Neighborhood Name_x'], axis=1)
combined_new.head()
# Out:
#    Year_x  Neighborhood Code Nationality  Number_x  Year_y  District Code_y  \
# 0    2017                  1       Spain      1109    2017                1
# 1    2017                  1       Spain      1109    2017                1
# 2    2017                  1       Spain      1109    2017                1
# 3    2017                  1       Spain      1109    2017                1
# 4    2017                  1       Spain      1109    2017                1
#
#   District Name_y Neighborhood Name_y  Gender      Demand_occupation  Number_y
# 0    Ciutat Vella            el Raval    Male  Registered unemployed      2107
# 1    Ciutat Vella            el Raval    Male    Unemployment demand       429
# 2    Ciutat Vella            el Raval  Female  Registered unemployed      1452
# 3    Ciutat Vella            el Raval  Female    Unemployment demand       288
# 4    Ciutat Vella            el Raval    Male  Registered unemployed      2063

# %%
# Rename column titles

combined_new = combined_new.rename(columns={'Year_x': 'Year_Unemployment', 'Year_y': 'Year_Immigrant','District Code_y':'District Code', 'District Name_y':'District_Name','Neighborhood Name_y':'Neighborhood Name','Number_y':'Number_Immigrants','Number_x':'Number_Unemployed'})

# %%
combined_new.tail()
# Out:
#          Year_Unemployment  Neighborhood Code     Nationality  \
# 6763003               2015                 99  No information
# 6763004               2015                 99  No information
# 6763005               2015                 99  No information
# 6763006               2015                 99  No information
# 6763007               2015                 99  No information
#
#          Number_Unemployed  Year_Immigrant  District Code District_Name  \
# 6763003                  0            2013             99     No consta
# 6763004                  0            2013             99     No consta
# 6763005                  0            2013             99     No consta
# 6763006                  0            2013             99     No consta
# 6763007                  0            2013             99     No consta
#
#         Neighborhood Name  Gender      Demand_occupation  Number_Immigrants
# 6763003         No consta  Female  Registered unemployed                  4
# 6763004         No consta    Male  Registered unemployed                  0
# 6763005         No consta  Female  Registered unemployed                  1
# 6763006         No consta    Male  Registered unemployed                  1
# 6763007         No consta  Female  Registered unemployed                  0

# %%
# Changing the column order

column_order = ['Neighborhood Code','Neighborhood Name','District Code','District_Name', 

                'Gender','Nationality','Demand_occupation', 

                'Year_Unemployment','Number_Unemployed','Year_Immigrant', 

                'Number_Immigrants'] 

  

combined_new = combined_new[column_order]

# %%
combined_new.head(56)
# Out:
#     Neighborhood Code Neighborhood Name  District Code District_Name  Gender  \
# 0                   1          el Raval              1  Ciutat Vella    Male
# 1                   1          el Raval              1  Ciutat Vella    Male
# 2                   1          el Raval              1  Ciutat Vella  Female
# 3                   1          el Raval              1  Ciutat Vella  Female
# 4                   1          el Raval              1  Ciutat Vella    Male
# 5                   1          el Raval              1  Ciutat Vella    Male
# 6                   1          el Raval              1  Ciutat Vella  Female
# 7                   1          el Raval              1  Ciutat Vella  Female
# 8                   1          el Raval              1  Ciutat Vella    Male
# 9                   1          el Raval              1  Ciutat Vella    Male
# 10                  1          el Raval              1  Ciutat Vella  Female
# 11                  1          el Raval              1  Ciutat Vella  Female
# 12                  1          el Raval              1  Ciutat Vella    Male
# 13                  1          el Raval              1  Ciutat Vella    Male
# 14                  1          el Raval              1  Ciutat Vella  Female
# 15                  1          el Raval              1  Ciutat Vella  Female
# 16                  1          el Raval              1  Ciutat Vella    Male
# 17                  1          el Raval              1  Ciutat Vella    Male
# 18                  1          el Raval              1  Ciutat Vella  Female
# 19                  1          el Raval              1  Ciutat Vella  Female
# 20                  1          el Raval              1  Ciutat Vella    Male
# 21                  1          el Raval              1  Ciutat Vella    Male
# 22                  1          el Raval              1  Ciutat Vella  Female
# 23                  1          el Raval              1  Ciutat Vella  Female
# 24                  1          el Raval              1  Ciutat Vella    Male
# 25                  1          el Raval              1  Ciutat Vella    Male
# 26                  1          el Raval              1  Ciutat Vella  Female
# 27                  1          el Raval              1  Ciutat Vella  Female
# 28                  1          el Raval              1  Ciutat Vella    Male
# 29                  1          el Raval              1  Ciutat Vella    Male
# 30                  1          el Raval              1  Ciutat Vella  Female
# 31                  1          el Raval              1  Ciutat Vella  Female
# 32                  1          el Raval              1  Ciutat Vella    Male
# 33                  1          el Raval              1  Ciutat Vella    Male
# 34                  1          el Raval              1  Ciutat Vella  Female
# 35                  1          el Raval              1  Ciutat Vella  Female
# 36                  1          el Raval              1  Ciutat Vella    Male
# 37                  1          el Raval              1  Ciutat Vella    Male
# 38                  1          el Raval              1  Ciutat Vella  Female
# 39                  1          el Raval              1  Ciutat Vella  Female
# 40                  1          el Raval              1  Ciutat Vella    Male
# 41                  1          el Raval              1  Ciutat Vella    Male
# 42                  1          el Raval              1  Ciutat Vella  Female
# 43                  1          el Raval              1  Ciutat Vella  Female
# 44                  1          el Raval              1  Ciutat Vella    Male
# 45                  1          el Raval              1  Ciutat Vella    Male
# 46                  1          el Raval              1  Ciutat Vella  Female
# 47                  1          el Raval              1  Ciutat Vella  Female
# 48                  1          el Raval              1  Ciutat Vella    Male
# 49                  1          el Raval              1  Ciutat Vella    Male
# 50                  1          el Raval              1  Ciutat Vella  Female
# 51                  1          el Raval              1  Ciutat Vella  Female
# 52                  1          el Raval              1  Ciutat Vella    Male
# 53                  1          el Raval              1  Ciutat Vella    Male
# 54                  1          el Raval              1  Ciutat Vella  Female
# 55                  1          el Raval              1  Ciutat Vella  Female
#
#    Nationality      Demand_occupation  Year_Unemployment  Number_Unemployed  \
# 0        Spain  Registered unemployed               2017               1109
# 1        Spain    Unemployment demand               2017               1109
# 2        Spain  Registered unemployed               2017               1109
# 3        Spain    Unemployment demand               2017               1109
# 4        Spain  Registered unemployed               2017               1109
# 5        Spain    Unemployment demand               2017               1109
# 6        Spain  Registered unemployed               2017               1109
# 7        Spain    Unemployment demand               2017               1109
# 8        Spain  Registered unemployed               2017               1109
# 9        Spain    Unemployment demand               2017               1109
# 10       Spain  Registered unemployed               2017               1109
# 11       Spain    Unemployment demand               2017               1109
# 12       Spain  Registered unemployed               2017               1109
# 13       Spain    Unemployment demand               2017               1109
# 14       Spain  Registered unemployed               2017               1109
# 15       Spain    Unemployment demand               2017               1109
# 16       Spain  Registered unemployed               2017               1109
# 17       Spain    Unemployment demand               2017               1109
# 18       Spain  Registered unemployed               2017               1109
# 19       Spain    Unemployment demand               2017               1109
# 20       Spain  Registered unemployed               2017               1109
# 21       Spain    Unemployment demand               2017               1109
# 22       Spain  Registered unemployed               2017               1109
# 23       Spain    Unemployment demand               2017               1109
# 24       Spain  Registered unemployed               2017               1109
# 25       Spain    Unemployment demand               2017               1109
# 26       Spain  Registered unemployed               2017               1109
# 27       Spain    Unemployment demand               2017               1109
# 28       Spain  Registered unemployed               2017               1109
# 29       Spain    Unemployment demand               2017               1109
# 30       Spain  Registered unemployed               2017               1109
# 31       Spain    Unemployment demand               2017               1109
# 32       Spain  Registered unemployed               2017               1109
# 33       Spain    Unemployment demand               2017               1109
# 34       Spain  Registered unemployed               2017               1109
# 35       Spain    Unemployment demand               2017               1109
# 36       Spain  Registered unemployed               2017               1109
# 37       Spain    Unemployment demand               2017               1109
# 38       Spain  Registered unemployed               2017               1109
# 39       Spain    Unemployment demand               2017               1109
# 40       Spain  Registered unemployed               2017               1109
# 41       Spain    Unemployment demand               2017               1109
# 42       Spain  Registered unemployed               2017               1109
# 43       Spain    Unemployment demand               2017               1109
# 44       Spain  Registered unemployed               2017               1109
# 45       Spain    Unemployment demand               2017               1109
# 46       Spain  Registered unemployed               2017               1109
# 47       Spain    Unemployment demand               2017               1109
# 48       Spain  Registered unemployed               2017               1109
# 49       Spain    Unemployment demand               2017               1109
# 50       Spain  Registered unemployed               2017               1109
# 51       Spain    Unemployment demand               2017               1109
# 52       Spain  Registered unemployed               2017               1109
# 53       Spain    Unemployment demand               2017               1109
# 54       Spain  Registered unemployed               2017               1109
# 55       Spain    Unemployment demand               2017               1109
#
#     Year_Immigrant  Number_Immigrants
# 0             2017               2107
# 1             2017                429
# 2             2017               1452
# 3             2017                288
# 4             2017               2063
# 5             2017                471
# 6             2017               1462
# 7             2017                332
# 8             2017               2109
# 9             2017                448
# 10            2017               1488
# 11            2017                281
# 12            2017               2017
# 13            2017                424
# 14            2017               1432
# 15            2017                283
# 16            2017               2006
# 17            2017                419
# 18            2017               1434
# 19            2017                288
# 20            2017               1926
# 21            2017                404
# 22            2017               1394
# 23            2017                298
# 24            2017               1878
# 25            2017                386
# 26            2017               1354
# 27            2017                310
# 28            2017               1842
# 29            2017                381
# 30            2017               1337
# 31            2017                302
# 32            2017               1866
# 33            2017                394
# 34            2017               1351
# 35            2017                288
# 36            2017               1926
# 37            2017                427
# 38            2017               1408
# 39            2017                295
# 40            2017               2026
# 41            2017                470
# 42            2017               1485
# 43            2017                335
# 44            2017               1997
# 45            2017                478
# 46            2017               1456
# 47            2017                359
# 48            2016               2431
# 49            2016                455
# 50            2016               1545
# 51            2016                326
# 52            2016               2418
# 53            2016                462
# 54            2016               1510
# 55            2016                331

# %%
# Check for missing values

combined_new.isnull().sum()
# Out:
# Neighborhood Code    0
# Neighborhood Name    0
# District Code        0
# District_Name        0
# Gender               0
# Nationality          0
# Demand_occupation    0
# Year_Unemployment    0
# Number_Unemployed    0
# Year_Immigrant       0
# Number_Immigrants    0
# dtype: int64

# %%
# Check for missing values like No consta or No information (LIKE NO?)
